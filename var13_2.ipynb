# %% [markdown]
# Расчет мощности излучения, необходимой для осуществления радиосвязи заданного вида,
# производится по формуле (1) из приложения к варианту 1.

# %% [markdown]
# Рассчет проводим для волн длиной
# λ= 3,2 и 1,2 сантимеров
# 2-х значений коэф. шима   N= 1, 13
# Яркостная температура земли 300 К

# %% [markdown]
# Данные нам величины
# D2= 1
# η2= 0,92
# h= 260 км
# r= ? км
# Δf= 5500 кГц
# Вид радиосвязи - телевидение
#
# Для расчета мощности используются следующие величины:
# β – коэффициент различимости по напряженности поля (200);
# А2 – эффективная площадь приемной антенны, м2;
# D1 – коэффициент направленного действия передающей антенны;
# r – протяженность радиолинии, м;
# Δf – полоса пропускания приемника, Гц;
# q – коэффициент согласования; при отсутствии указаний полагать q = 1;
# ТА – шумовая температура приемной антенны, К;
# W – множитель ослабления;
# T0- температура при которой измеряеться коэф шума (Т0=300 К)
# Rз- радиус земли

# %%
D2=1 # эффективная площадь раскрыва
η2= 0.92
h= 260   # длина радиолинии в километрах
O=2.5     # Ширина диаграммы направленности передающей антенны равна
Δf= 5500*(10**3)  # полоса пропускания 
T0=300
radius=6370 # радиус земли в километрах

# %% [markdown]
# ### Сначала выполним расчеты для N=1

# %%
N_1=1

# %% [markdown]
# Шумовая температура радиоприемного устройства приближенно равна
# Tшрпу=(N-η2)*T0

# %%
Tnrpu_1=(N_1-η2)*T0
print(Tnrpu_1)
# Out:
# 23.99999999999999

# %% [markdown]
# Шумовая температура направленной  антенны вычисляется по формуле,
# где T_le-яркостная температура шумов Земли
# T_cos-яркостная температура космических шумов  (T_cos для каждой волны своя )
# T_a-яркостная температура атмосферных шумов (для каждого угла своя)
# k- коэф направленности антены (=12)

# %%
k=12
T_cos_4=3*(10**(-1))
T_cos_2=5*(10**(-2))

T_a_4_5=90
T_a_4_30=45
T_a_4_90=9

T_a_2_5=150
T_a_2_30=80
T_a_2_90=18

# %%
print('Расчеты для длины волны 3,1 см ')

# для угла 5 градусов
T_A_4_5=(k/16)*(T_cos_4+T_a_4_5+((16-k)/(2*k))*T0)
print('расчет Tа для 5 градусов')
print(T_A_4_5)

# для угла 30 градусов
T_A_4_30=(k/16)*(T_cos_4+T_a_4_30+((16-k)/(2*k))*T0)
print('расчет Tа для 30 градусов')
print(T_A_4_30)

# для угла 90 градусов
T_A_4_90=(k/16)*(T_cos_4+T_a_4_90+((16-k)/(2*k))*T0)
print('расчет Tа для 90 градусов')
print(T_A_4_90)

print('расчеты для дины волны 1,2 см')

# для угла 5 градусов
T_A_2_5=(k/16)*(T_cos_2+T_a_2_5+((16-k)/(2*k))*T0)
print('расчет Tа для 5 градусов')
print(T_A_2_5)

# для угла 30 градусов
T_A_2_30=(k/16)*(T_cos_2+T_a_2_30+((16-k)/(2*k))*T0)
print('расчет Tа для 30 градусов')
print(T_A_2_30)

# для угла 90 градусов
T_A_2_90=(k/16)*(T_cos_2+T_a_2_90+((16-k)/(2*k))*T0)
print('расчет Tа для 90 градусов')
print(T_A_2_90)
# Out:
# Расчеты для длины волны 3,2 см
# расчет Tа для 5 градусов
# 105.22500000000001
# расчет Tа для 30 градусов
# 71.475
# расчет Tа для 90 градусов
# 44.474999999999994
# расчеты для дины волны 1,2 см
# расчет Tа для 5 градусов
# 150.03750000000002
# расчет Tа для 30 градусов
# 97.53750000000001
# расчет Tа для 90 градусов
# 51.037499999999994

# %% [markdown]
# Расчитаем КНД приемной антены D1

# %%
D1=((25*(10**3))/((2.5)**2))
print(D1)
# Out:
# 4000.0

# %% [markdown]
# Расчитаем A2D1 через формулы для 1 и 2 длины волны

# %%
A2D1_1=(((2*(10**(-2)))**2)/(4*(355/113)))*D1*D2
print('для длины волны 3,1 см')
print(A2D1_1)
A2D1_2=(((1*(10**(-2)))**2)/(4*(355/113)))*D1*D2
print('для длины волны 1,2 см')
print(A2D1_2)
# Out:
# для длины волны 2 см
# 0.08841940532081377
# для длины волны 1 см
# 0.022104851330203443

# %% [markdown]
# рассчитаем множитель ослабления W

# %% [markdown]
# расчитаем длину радиолинии в метрах

# %%
rad=6370*(10**3)    # Радиус земли в метрах
hi=250*(10**3)      # Высота в метрах

# %% [markdown]
# Посчитаем моножитель ослабления W
# перед этим вычислим Г

# %%
i_k_2=2.8*(10**(-5))
print('коэф поглащения для кислорода и длины волны 1 см')
print(i_k_2)
i_p_2=9*(10**(-4))
print('коэф поглащения для паров и длины волны 1 см')
print(i_p_2)

i_k_4=3*(10**(-5))
print('коэф поглащения для кислорода и длины волны 2 см')
print(i_k_4)
i_p_4=3*(10**(-4))
print('коэф поглащения для паров и длины волны 2 см')
print(i_p_4)

h_k=5.5*(10**3)
h_p=2.2*(10**3)
# Out:
# коэф поглащения для кислорода и длины волны 1 см
# 2.8e-05
# коэф поглащения для паров и длины волны 1 см
# 0.0009000000000000001
# коэф поглащения для кислорода и длины волны 2 см
# 3.0000000000000004e-05
# коэф поглащения для паров и длины волны 2 см
# 0.00030000000000000003

# %%
from scipy.integrate import quad
from numpy import exp

integrand_2= lambda x: i_k_2*exp(-x/h_k)+i_p_2*exp(-x/h_p)

a = 0
b = hi
result, error = quad(integrand_2,0 , hi)

print('для длины волны 1 см')
g_5_2=(result/(0.087))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_5_2)

g_30_2=(result/(0.5))*0.115
print ("коэффициентом суммарного поглощения Г для 30 гр в неперах")
print(g_30_2)

g_90_2=(result/(1))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_90_2)

print()
integrand_3= lambda x: i_k_4*exp(-x/h_k)+i_p_4*exp(-x/h_p)

a = 0
b = hi
result, error = quad(integrand_3,0 , hi)

print('для длины волны 2 см')
g_5_4=(result/(0.087))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_5_4)

g_30_4=(result/(0.5))*0.115
print ("коэффициентом суммарного поглощения Г для 30 гр в неперах")
print(g_30_4)

g_90_4=(result/(1))*0.115
print ("коэффициентом суммарного поглощения Г для 90 гр в неперах")
print(g_90_4)
# Out:
# для длины волны 1 см
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 2.820804597701151
# коэффициентом суммарного поглощения Г для 30 гр в неперах
# 0.4908200000000002
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 0.2454100000000001
#
# для длины волны 2 см
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 1.0905172413793107
# коэффициентом суммарного поглощения Г для 30 гр в неперах
# 0.18975000000000006
# коэффициентом суммарного поглощения Г для 90 гр в неперах
# 0.09487500000000003

# %%
W_5_4=exp(-g_5_4)
print ('для длины волны 2 см угол 5 гр моножитель ослабления W='+f'{W_5_4}')
W_30_4=exp(-g_30_4)
print ('для длины волны 2 см угол 30 гр моножитель ослабления W='+f'{W_30_4}')
W_90_4=exp(-g_90_4)
print ('для длины волны 2 см угол 90 гр моножитель ослабления W='+f'{W_90_4}')

print()

W_5_2=exp(-g_5_2)
print ('для длины волны 1 см угол 5 гр моножитель ослабления W='+f'{W_5_2}')
W_30_2=exp(-g_30_2)
print ('для длины волны 1 см угол 30 гр моножитель ослабления W='+f'{W_30_2}')
W_90_2=exp(-g_90_2)
print ('для длины волны 1 см угол 90 гр моножитель ослабления W='+f'{W_90_2}')
# Out:
# для длины волны 2 см угол 5 гр моножитель ослабления W=0.33604263359148057
# для длины волны 2 см угол 30 гр моножитель ослабления W=0.8271658995714747
# для длины волны 2 см угол 90 гр моножитель ослабления W=0.909486613189812
#
# для длины волны 1 см угол 5 гр моножитель ослабления W=0.05955800319305918
# для длины волны 1 см угол 30 гр моножитель ослабления W=0.6121242464498929
# для длины волны 1 см угол 90 гр моножитель ослабления W=0.7823836951585155

# %% [markdown]
# расчитаем длину радиолинии для каждого угла

# %%
from math import sqrt
print('бери только положительные значения в круглых скобках')
def quadratic_solve(a ,b, c):
    if not all(
        map(
            lambda p: isinstance(p, (int, float)),
            (a, b, c)
        )
    ):
        raise TypeError("Not valid argument type")
    #print("Types are OK")

    if a == 0:
        if b == 0:
            # a и b 0: решения нет
            return None, None
        return -c / b, None
    d = b ** 2 - 4 * a * c
    if d < 0:
        return None, None

    d_root = sqrt(d)
    divider = 2 * a
    x1 = (-b + d_root) / divider
    x2 = (-b - d_root) / divider

    if d == 0:
        x2 = None
    elif x2 > x1:
        x1, x2 = x2, x1

    return x1, x2
print ('для угла 5 гр ')
print(quadratic_solve(1,1110,-3247500))
r_5=1330*(10**3)

print ('для угла 30 гр ')
print(quadratic_solve(1,6370,-3247500))
r_30=474*(10**3)

print ('для угла 90 гр ')
print(quadratic_solve(1,12740,-3247500))
r_90=250*(10**3)
# Out:
# бери только положительные значения в круглых скобках
# для угла 5 гр
# (1330.6099808815184, -2440.6099808815184)
# для угла 30 гр
# (474.47059012639147, -6844.4705901263915)
# для угла 90 гр
# (250.0, -12990.0)

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=200

# %%
β_10=200

# %%
P_1_5_4= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_1*(W_5_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_5 +1*(Tnrpu_1/η2) )
P_1_30_4= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_1*(W_30_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_30 +1*(Tnrpu_1/η2) )
P_1_90_4= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_1*(W_90_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_90 +1*(Tnrpu_1/η2) )

print('Расчет мощности излучения для длины волны 2 см 5 гр '+f'{P_1_5_4} Вт')
print('Расчет мощности излучения для длины волны 2 см 30 гр '+f'{P_1_30_4} Вт')
print('Расчет мощности излучения для длины волны 2 см 90 гр '+f'{P_1_90_4} Вт')

print()
P_1_5_2= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_2*(W_5_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_5 +1*(Tnrpu_1/η2) )
P_1_30_2= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_2*(W_30_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_30 +1*(Tnrpu_1/η2) )
P_1_90_2= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_2*(W_90_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_90 +1*(Tnrpu_1/η2) )

print('Расчет мощности излучения для длины волны 1 см 5 гр '+f'{P_1_5_2} Вт')
print('Расчет мощности излучения для длины волны 1 см 30 гр '+f'{P_1_30_2} Вт')
print('Расчет мощности излучения для длины волны 1 см 90 гр '+f'{P_1_90_2} Вт')
# Out:
# Расчет мощности излучения для длины волны 2 см 5 гр 1352285.7346759422 Вт
# Расчет мощности излучения для длины волны 2 см 30 гр 19074.017251926834 Вт
# Расчет мощности излучения для длины волны 2 см 90 гр 2868.460631773156 Вт
#
# Расчет мощности излучения для длины волны 1 см 5 гр 172194469.78358114 Вт
# Расчет мощности излучения для длины волны 1 см 30 гр 139309.85673883508 Вт
# Расчет мощности излучения для длины волны 1 см 90 гр 15791.572842673317 Вт

# %% [markdown]
# ### Теперь посчитаем для N=5

# %%
N_5=5

# %%
Tnrpu_10=(N_5-η2)*T0
print(Tnrpu_10)
# Out:
# 1230.0

# %%
P_10_5_4= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_1*(W_5_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_5 +1*(Tnrpu_10/η2) )
P_10_30_4= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_1*(W_30_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_30 +1*(Tnrpu_10/η2) )
P_10_90_4= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_1*(W_90_4**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_4_90 +1*(Tnrpu_10/η2) )

print('Расчет мощности излучения для длины волны 4 см 5 гр '+f'{P_10_5_4} Вт')
print('Расчет мощности излучения для длины волны 4 см 30 гр '+f'{P_10_30_4} Вт')
print('Расчет мощности излучения для длины волны 4 см 90 гр '+f'{P_10_90_4} Вт')

print()

P_10_5_2= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_2*(W_5_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_5 +1*(Tnrpu_10/η2) )
P_10_30_2= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_2*(W_30_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_30 +1*(Tnrpu_10/η2) )
P_10_90_2= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_2*(W_90_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_90 +1*(Tnrpu_10/η2) )

print('Расчет мощности излучения для длины волны 2 см 5 гр '+f'{P_10_5_2} Вт')
print('Расчет мощности излучения для длины волны 2 см 30 гр '+f'{P_10_30_2} Вт')
print('Расчет мощности излучения для длины волны 2 см 90 гр '+f'{P_10_90_2} Вт')
# Out:
# Расчет мощности излучения для длины волны 4 см 5 гр 11183471.413955424 Вт
# Расчет мощности излучения для длины волны 4 см 30 гр 225166.81513337645 Вт
# Расчет мощности излучения для длины волны 4 см 90 гр 50290.34107149841 Вт
#
# Расчет мощности излучения для длины волны 2 см 5 гр 1424108169.1807325 Вт
# Расчет мощности излучения для длины волны 2 см 30 гр 1644630.044094555 Вт
# Расчет мощности излучения для длины волны 2 см 90 гр 272117.06637306034 Вт
