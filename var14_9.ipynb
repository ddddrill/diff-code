# %% [markdown]
# Расчет мощности излучения, необходимой для осуществления радиосвязи заданного вида,
# производится по формуле (1) из приложения к варианту 1.

# %% [markdown]
# Рассчет проводим для волн длиной
# λ=2,0 и 3,2 сантимеров
# 2-х значений коэф. шима   N= 1, 15
# Яркостная температура земли 300 К

# %% [markdown]
# Данные нам величины
# D1= 1
# η2= 0,94
# h= 750 км
# r= ? км
# Δf= 4 кГц
# Вид радиосвязи - телефония
#
# Для расчета мощности используются следующие величины:
# β – коэффициент различимости по напряженности поля (25);
# А2 – эффективная площадь приемной антенны, м2;
# D1 – коэффициент направленного действия передающей антенны;
# r – протяженность радиолинии, м;
# Δf – полоса пропускания приемника, Гц;
# q – коэффициент согласования; при отсутствии указаний полагать q = 1;
# ТА – шумовая температура приемной антенны, К;
# W – множитель ослабления;
# T0- температура при которой измеряеться коэф шума (Т0=300 К)
# Rз- радиус земли

# %%
D1=1 # эффективная площадь раскрыва
η2= 0.93
h= 700   # длина радиолинии в километрах
O=5
Δf= 100*(10**3)  # полоса пропускания 
T0=300
radius=6370 # радиус земли в километрах

# %% [markdown]
# ### Сначала выполним расчеты для N=1

# %%
N_1=1

# %% [markdown]
# Шумовая температура радиоприемного устройства приближенно равна
# Tшрпу=(N-η2)*T0

# %%
Tnrpu_1=(N_1-η2)*T0
print(Tnrpu_1)
# Out:
# 20.999999999999986

# %% [markdown]
# Шумовая температура направленной  антенны вычисляется по формуле,
# где T_le-яркостная температура шумов Земли
# T_cos-яркостная температура космических шумов  (T_cos для каждой волны своя )
# T_a-яркостная температура атмосферных шумов (для каждого угла своя)
# k- коэф направленности антены (=12)

# %%
k=12
T_cos_3=3*(10**(-1))
T_cos_2=1*(10**(-1))

T_a_3_5=90
T_a_3_30=40
T_a_3_90=8

T_a_2_5=150
T_a_2_30=60
T_a_2_90=14

# %%
# Расчеты для длины волны 3,2 см 

# для угла 5 градусов
T_A_3_5=(k/16)*(T_cos_3+T_a_3_5+((16-k)/(2*k))*T0)
print(T_A_3_5)

# для угла 30 градусов
T_A_3_30=(k/16)*(T_cos_3+T_a_3_30+((16-k)/(2*k))*T0)
print(T_A_3_30)

# для угла 90 градусов
T_A_3_90=(k/16)*(T_cos_3+T_a_3_90+((16-k)/(2*k))*T0)
print(T_A_3_90)

# расчеты для дины волны 2 см

# для угла 5 градусов
T_A_2_5=(k/16)*(T_cos_2+T_a_2_5+((16-k)/(2*k))*T0)
print(T_A_2_5)

# для угла 30 градусов
T_A_2_30=(k/16)*(T_cos_2+T_a_2_30+((16-k)/(2*k))*T0)
print(T_A_2_30)

# для угла 90 градусов
T_A_2_90=(k/16)*(T_cos_2+T_a_2_90+((16-k)/(2*k))*T0)
print(T_A_2_90)
# Out:
# 105.22500000000001
# 67.725
# 43.724999999999994
# 150.075
# 82.57499999999999
# 48.074999999999996

# %% [markdown]
# Расчитаем КНД приемной антены D2

# %%
D2=((25*(10**3))/((5)**2))
print(D2)
# Out:
# 1000.0

# %% [markdown]
# Расчитаем A2D1 через формулы для 1 и 2 длины волны

# %%
A2D1_1=(((3.5*(10**(-2)))**2)/(4*(355/113)))*D1*D2
print(A2D1_1)
A2D1_2=(((2.1*(10**(-2)))**2)/(4*(355/113)))*D1*D2
print(A2D1_2)
# Out:
# 0.0974823943661972
# 0.03509366197183099

# %% [markdown]
# рассчитаем множитель ослабления W

# %% [markdown]
# расчитаем длину радиолинии в метрах

# %%
rad=6370*(10**3)    # Радиус земли в метрах
hi=700*(10**3)      # Высота в метрах

# %% [markdown]
# Посчитаем моножитель ослабления W
# перед этим вычислим Г

# %%
i_k_2=3.2*(10**(-5))
i_p_2=3*(10**(-4))

i_k_3=5*(10**(-5))
i_p_3=8*(10**(-5))

h_k=5.5*(10**3)
h_p=2.2*(10**3)

# %%
from scipy.integrate import quad
from numpy import exp

integrand_2= lambda x: i_k_2*exp(-x/h_k)+i_p_2*exp(-x/h_p)

a = 0
b = hi
result, error = quad(integrand_2,0 , hi)

print('для длины волны 2,1 см')
g_5_2=(result/(0.087))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_5_2)

g_30_2=(result/(0.5))*0.115
print ("коэффициентом суммарного поглощения Г для 30 гр в неперах")
print(g_30_2)

g_90_2=(result/(1))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_90_2)

print()
integrand_3= lambda x: i_k_3*exp(-x/h_k)+i_p_3*exp(-x/h_p)

a = 0
b = hi
result, error = quad(integrand_3,0 , hi)

print('для длины волны 3,5 см')
g_5_3=(result/(0.087))*0.115
print ("коэффициентом суммарного поглощения Г для 5 гр в неперах")
print(g_5_3)

g_30_3=(result/(0.5))*0.115
print ("коэффициентом суммарного поглощения Г для 30 гр в неперах")
print(g_30_3)

g_90_3=(result/(1))*0.115
print ("коэффициентом суммарного поглощения Г для 90 гр в неперах")
print(g_90_3)
# Out:
# для длины волны 2,1 см
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 1.1050574712643682
# коэффициентом суммарного поглощения Г для 30 гр в неперах
# 0.19228000000000006
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 0.09614000000000003
#
# для длины волны 3,5 см
# коэффициентом суммарного поглощения Г для 5 гр в неперах
# 0.5961494252873565
# коэффициентом суммарного поглощения Г для 30 гр в неперах
# 0.10373000000000002
# коэффициентом суммарного поглощения Г для 90 гр в неперах
# 0.05186500000000001

# %%
W_5_3=exp(-g_5_3)
print ('для длины волны 3,5 см угол 5 гр моножитель ослабления W='+f'{W_5_3}')
W_30_3=exp(-g_30_3)
print ('для длины волны 3,5 см угол 30 гр моножитель ослабления W='+f'{W_30_3}')
W_90_3=exp(-g_90_3)
print ('для длины волны 3,5 см угол 90 гр моножитель ослабления W='+f'{W_90_3}')

print()

W_5_2=exp(-g_5_2)
print ('для длины волны 2,1 см угол 5 гр моножитель ослабления W='+f'{W_5_2}')
W_30_2=exp(-g_30_2)
print ('для длины волны 2,1 см угол 30 гр моножитель ослабления W='+f'{W_30_2}')
W_90_2=exp(-g_90_2)
print ('для длины волны 2,1 см угол 90 гр моножитель ослабления W='+f'{W_90_2}')
# Out:
# для длины волны 3,5 см угол 5 гр моножитель ослабления W=0.5509289501238014
# для длины волны 3,5 см угол 30 гр моножитель ослабления W=0.9014686611041273
# для длины волны 3,5 см угол 90 гр моножитель ослабления W=0.9494570348910619
#
# для длины волны 2,1 см угол 5 гр моножитель ослабления W=0.33119184768078147
# для длины волны 2,1 см угол 30 гр моножитель ослабления W=0.8250758149175146
# для длины волны 2,1 см угол 90 гр моножитель ослабления W=0.9083368400089884

# %% [markdown]
# расчитаем длину радиолинии для каждого угла

# %%
from math import sqrt

def quadratic_solve(a ,b, c):
    if not all(
        map(
            lambda p: isinstance(p, (int, float)),
            (a, b, c)
        )
    ):
        raise TypeError("Not valid argument type")
    print("Types are OK")

    if a == 0:
        if b == 0:
            # a и b 0: решения нет
            return None, None
        return -c / b, None
    d = b ** 2 - 4 * a * c
    if d < 0:
        return None, None

    d_root = sqrt(d)
    divider = 2 * a
    x1 = (-b + d_root) / divider
    x2 = (-b - d_root) / divider

    if d == 0:
        x2 = None
    elif x2 > x1:
        x1, x2 = x2, x1

    return x1, x2
print ('для угла 5 гр ')
print(quadratic_solve(1,1110,-9408000))
r_5=2562*(10**3)

print ('для угла 30 гр ')
print(quadratic_solve(1,6370,-9408000))
r_30=1236*(10**3)

print ('для угла 90 гр ')
print(quadratic_solve(1,12740,-9408000))
r_90=700*(10**3)
# Out:
# для угла 5 гр
# Types are OK
# (2562.053897512842, -3672.053897512842)
# для угла 30 гр
# Types are OK
# (1236.7897959989004, -7606.7897959989)
# для угла 90 гр
# Types are OK
# (700.0, -13440.0)

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=5

# %%
β_10=5

# %%
P_1_5_3= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_1*(W_5_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_5 +1*(Tnrpu_1/η2) )
P_1_30_3= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_1*(W_30_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_30 +1*(Tnrpu_1/η2) )
P_1_90_3= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_1*(W_90_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_90 +1*(Tnrpu_1/η2) )

print('Расчет мощности излучения для длины волны 3,5 см 5 гр '+f'{P_1_5_3} Вт')
print('Расчет мощности излучения для длины волны 3,5 см 30 гр '+f'{P_1_30_3} Вт')
print('Расчет мощности излучения для длины волны 3,5 см 90 гр '+f'{P_1_90_3} Вт')

print()
P_1_5_2= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_2*(W_5_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_5 +1*(Tnrpu_1/η2) )
P_1_30_2= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_2*(W_30_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_30 +1*(Tnrpu_1/η2) )
P_1_90_2= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_2*(W_90_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_90 +1*(Tnrpu_1/η2) )

print('Расчет мощности излучения для длины волны 2,1 см 5 гр '+f'{P_1_5_2} Вт')
print('Расчет мощности излучения для длины волны 2,1 см 30 гр '+f'{P_1_30_2} Вт')
print('Расчет мощности излучения для длины волны 2,1 см 90 гр '+f'{P_1_90_2} Вт')
# Out:
# Расчет мощности излучения для длины волны 3,5 см 5 гр 12.291925165386312 Вт
# Расчет мощности излучения для длины волны 3,5 см 30 гр 0.7550111799296589 Вт
# Расчет мощности излучения для длины волны 3,5 см 90 гр 0.16028716955959113 Вт
#
# Расчет мощности излучения для длины волны 2,1 см 5 гр 127.63802183579044 Вт
# Расчет мощности излучения для длины волны 2,1 см 30 гр 2.915292444833324 Вт
# Расчет мощности излучения для длины волны 2,1 см 90 гр 0.5183813838553282 Вт

# %% [markdown]
# ### Теперь посчитаем для N=7

# %%
N_7=7

# %%
Tnrpu_10=(N_7-η2)*T0
print(Tnrpu_10)
# Out:
# 1821.0

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=5

# %%
P_10_5_3= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_1*(W_5_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_5 +1*(Tnrpu_10/η2) )
P_10_30_3= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_1*(W_30_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_30 +1*(Tnrpu_10/η2) )
P_10_90_3= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_1*(W_90_3**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_3_90 +1*(Tnrpu_10/η2) )

print('Расчет мощности излучения для длины волны 3,5 см 5 гр '+f'{P_10_5_3} Вт')
print('Расчет мощности излучения для длины волны 3,5 см 30 гр '+f'{P_10_30_3} Вт')
print('Расчет мощности излучения для длины волны 3,5 см 90 гр '+f'{P_10_90_3} Вт')

print()

P_10_5_2= (β_10**2)* ( (4*(355/113)*(r_5**2)) / (A2D1_2*(W_5_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_5 +1*(Tnrpu_10/η2) )
P_10_30_2= (β_10**2)* ( (4*(355/113)*(r_30**2)) / (A2D1_2*(W_30_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_30 +1*(Tnrpu_10/η2) )
P_10_90_2= (β_10**2)* ( (4*(355/113)*(r_90**2)) / (A2D1_2*(W_90_2**2))) * ((138/100)*(10**(-23))) * (Δf) * ( T_A_2_90 +1*(Tnrpu_10/η2) )

print('Расчет мощности излучения для длины волны 2,1 см 5 гр '+f'{P_10_5_2} Вт')
print('Расчет мощности излучения для длины волны 2,1 см 30 гр '+f'{P_10_30_2} Вт')
print('Расчет мощности излучения для длины волны 2,1 см 90 гр '+f'{P_10_90_2} Вт')
# Out:
# Расчет мощности излучения для длины волны 3,5 см 5 гр 198.44037636035316 Вт
# Расчет мощности излучения для длины волны 3,5 см 30 гр 16.936856274377565 Вт
# Расчет мощности излучения для длины волны 3,5 см 90 гр 4.8391230462185 Вт
#
# Расчет мощности излучения для длины волны 2,1 см 5 гр 1558.4706618842604 Вт
# Расчет мощности излучения для длины волны 2,1 см 30 гр 56.57386205823266 Вт
# Расчет мощности излучения для длины волны 2,1 см 90 гр 14.718503754425772 Вт
