# %% [markdown]
# # <p style="padding:10px;background-color:#0f4c5c;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">U-Net: Massachusetts Building Segmentation</p>
#
# <p style="text-align:justify; ">
#
# Satellite images are one of the most powerful and important tools we have for monitoring the earth. They track the physical environment (water, air, land, vegetation) and the changing human footprint across the globe. Satellite imagery is used to measure, identify and track human activity. The technique of segmenting the satellite images helps us to develop the topographic details of the geographical area captured by the satellite.
#
# Image segmentation is a commonly used technique in digital image processing and analysis to partition an image into multiple parts or regions, often based on the characteristics of the pixels in the image.
#     Satellite remote sensing has become one of the most efficient solutions for surveying the earth at local, regional, and global spatial scales.
# </p>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#a7fabd;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# !pip install torch-snippets==0.495
from torch_snippets import *

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#a7fabd;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">Dataset</p>

# %% [markdown]
# The dataset consists of $151$ aerial images of the Boston area. It covers mostly urban and suburban areas and buildings of all sizes. Each of the images has $1500 \times 1500$ pixels for an area of $2.25$ square kilometers. In total the dataset covers $340$ square kilometers area.
#
# An accompanying **metadata.csv** is provided with each image ID, the split it belongs to, image urls and path to it.

# %%
IMG_ROOT = 'E:/mphti/training/building segment/data/'
df = pd.read_csv('E:/mphti/training/building segment/data/metadata.csv')

train_df = df.loc[df['split'] == 'train']
tst_df = df.loc[df['split'] == 'test']
print("Training dataset size:", len(train_df))
print("Test dataset size:", len(tst_df))
# Out:
# Training dataset size: 137
# Test dataset size: 10

# %%
import cv2
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

tfms = transforms.Compose([
#     transforms.RandomHorizontalFlip(0.3),
#     transforms.RandomRotation(40),
#     transforms.RandomVerticalFlip(0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], # imagenet
                         [0.229, 0.224, 0.225])
])

class BuildingDatasetHighRes(Dataset):
    """
    Dataset for high-resolution building segmentation (512x512).
    """
    def __init__(self, df, root=IMG_ROOT, img_size=256):
        self.df = df
        self.root = root
        self.img_size = img_size
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        img_path = self.root + self.df.iloc[idx]['png_image_path']
        mask_path = self.root + self.df.iloc[idx]['png_label_path']
        
        img = cv2.imread(img_path)
        mask = cv2.imread(mask_path)
        
        # Resize to 512x512
        img = cv2.resize(img, (self.img_size, self.img_size))
        mask = cv2.resize(mask, (self.img_size, self.img_size))
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
        
        return img, mask
    
    def collate_fn(self, batch):
        images, masks = list(zip(*batch))
        images = torch.cat([tfms(img.copy()/255.)[None] for img in images]).float().to(device)
        masks = torch.cat([torch.tensor(mask)[None] for mask in masks]).float().to(device)
        return images, masks
    
tr_ds = BuildingDatasetHighRes(train_df)
tst_ds = BuildingDatasetHighRes(tst_df)

tr_dl = DataLoader(tr_ds, batch_size=4, drop_last=True, shuffle=True,
                  collate_fn=tr_ds.collate_fn)
tst_dl = DataLoader(tst_ds, batch_size=1, drop_last=True, shuffle=True,
                  collate_fn=tst_ds.collate_fn)

img, mask = tr_ds[11]
fig, ax = plt.subplots(1, 2)
show(img, ax=ax[0])
show(mask, ax=ax[1])

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#a7fabd;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">Model</p>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# NEW COMPONENTS FOR HIGHER RESOLUTION AND QUALITY

class ResidualBlock(nn.Module):
    """
    Остаточный блок (Residual Block) для улучшенного градиентного потока.
    Позволяет сети обучаться более глубоким признакам без деградации.
    """
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                               stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, 
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        # Shortcut для matching размеров
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, 
                         stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
    
    def forward(self, x):
        residual = x
        
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        
        out += self.shortcut(residual)
        out = self.relu(out)
        
        return out


class AttentionGate(nn.Module):
    """
    Блок внимания (Attention Gate) для фокусировки на важных регионах.
    Помогает модели лучше определять границы зданий.
    """
    def __init__(self, F_g, F_l, F_int):
        super(AttentionGate, self).__init__()
        
        # Gating signal
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(F_int)
        )
        
        # Skip connection
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(F_int)
        )
        
        # Attention coefficients
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
        self.relu = nn.ReLU(inplace=True)
    
    def forward(self, g, x):
        # g: gating signal from decoder
        # x: skip connection from encoder
        
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        
        # Add and apply ReLU
        psi = self.relu(g1 + x1)
        
        # Apply sigmoid to get attention coefficients
        psi = self.psi(psi)
        
        # Weight the skip connection
        return x * psi


class ConvBlock(nn.Module):
    """
    Улучшенный сверточный блок с BatchNorm.
    """
    def __init__(self, in_channels, out_channels, dropout=0.0):
        super(ConvBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Dropout2d(dropout) if dropout > 0 else nn.Identity(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
    
    def forward(self, x):
        return self.conv(x)


def up_conv(in_channels, out_channels):
    """Transposed convolution for upsampling."""
    return nn.Sequential(
        nn.ConvTranspose2d(in_channels, out_channels, 
                           kernel_size=2, stride=2),
        nn.ReLU(inplace=True)
    )


# ENHANCED U-NET MODEL

class UNet(nn.Module):
    """
    Enhanced U-Net with Residual Blocks and Attention Gates.
    
    KEY IMPROVEMENTS:
    - Input size: 512x512 (vs 224x224 in original)
    - Residual Blocks for better gradient flow
    - Attention Gates for better boundary detection
    - Increased filters: 64 -> 128 -> 256 -> 512 -> 1024
    
    Args:
        in_channels: Number of input channels (3 for RGB)
        out_channels: Number of output channels (1 for binary segmentation)
        base_filters: Base number of filters (64)
    """
    def __init__(self, in_channels=3, out_channels=1, base_filters=64):
        super(UNet, self).__init__()
        
        # Encoder - с увеличенным количеством фильтров
        self.enc1 = ConvBlock(in_channels, base_filters)          # 64
        self.enc2 = ConvBlock(base_filters, base_filters * 2)      # 128
        self.enc3 = ConvBlock(base_filters * 2, base_filters * 4) # 256
        self.enc4 = ConvBlock(base_filters * 4, base_filters * 8) # 512
        
        # Bottleneck
        self.bottleneck = ResidualBlock(base_filters * 8, base_filters * 16)  # 1024
        
        # Decoder с Attention Gates
        self.up_conv4 = up_conv(base_filters * 16, base_filters * 8)
        self.att4 = AttentionGate(F_g=base_filters * 8, F_l=base_filters * 8, F_int=base_filters * 4)
        self.dec4 = ConvBlock(base_filters * 16, base_filters * 8)
        
        self.up_conv3 = up_conv(base_filters * 8, base_filters * 4)
        self.att3 = AttentionGate(F_g=base_filters * 4, F_l=base_filters * 4, F_int=base_filters * 2)
        self.dec3 = ConvBlock(base_filters * 8, base_filters * 4)
        
        self.up_conv2 = up_conv(base_filters * 4, base_filters * 2)
        self.att2 = AttentionGate(F_g=base_filters * 2, F_l=base_filters * 2, F_int=base_filters)
        self.dec2 = ConvBlock(base_filters * 4, base_filters * 2)
        
        self.up_conv1 = up_conv(base_filters * 2, base_filters)
        self.att1 = AttentionGate(F_g=base_filters, F_l=base_filters, F_int=base_filters // 2)
        self.dec1 = ConvBlock(base_filters * 2, base_filters)
        
        # Output layer
        self.final_conv = nn.Conv2d(base_filters, out_channels, kernel_size=1)
        
        self.pool = nn.MaxPool2d(2)
        
    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        
        # Bottleneck
        b = self.bottleneck(self.pool(e4))
        
        # Decoder с Attention
        d4 = self.up_conv4(b)
        e4_att = self.att4(g=d4, x=e4)
        d4 = self.dec4(torch.cat([d4, e4_att], dim=1))
        
        d3 = self.up_conv3(d4)
        e3_att = self.att3(g=d3, x=e3)
        d3 = self.dec3(torch.cat([d3, e3_att], dim=1))
        
        d2 = self.up_conv2(d3)
        e2_att = self.att2(g=d2, x=e2)
        d2 = self.dec2(torch.cat([d2, e2_att], dim=1))
        
        d1 = self.up_conv1(d2)
        e1_att = self.att1(g=d1, x=e1)
        d1 = self.dec1(torch.cat([d1, e1_att], dim=1))
        
        return self.final_conv(d1)

# MODEL INITIALIZATION

# Параметры для новой модели
IMG_SIZE = 256  # Увеличенный размер изображения

# Инициализация новой модели
model = UNet(in_channels=3, out_channels=1, base_filters=64).to(device)

# Тест модели
x = torch.randn(1, 3, 256, 256).to(device)
y = model(x)
print(f"Input shape: {x.shape}")
print(f"Output shape: {y.shape}")
# Out:
# Input shape: torch.Size([1, 3, 256, 256])
# Output shape: torch.Size([1, 1, 256, 256])

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#a7fabd;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">Training</p>

# %%
# Очистите CUDA и перезапустите
import torch
torch.cuda.empty_cache()

# Или используйте более старый метод
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def loss_fn(preds, targets):
    # Преобразуем маску: все что > 0 становится 1, остальное 0
    # Это критически важно, если в маске значения 255
    targets = (targets > 0).long()
    
    criterion = nn.CrossEntropyLoss()
    loss = criterion(preds, targets)
    
    # Для точности: берем индекс максимального значения
    acc = (torch.argmax(preds, dim=1) == targets).float().mean()
    return loss, acc

def train_batch(model, batch, optim, loss_fn):
    model.train()
    imgs, masks = batch
    
    # Проверка размерностей для отладки
    # print("Preds shape will be:", imgs.shape) 
    # print("Masks shape:", masks.shape, "Unique values:", torch.unique(masks))
    
    # Если маски имеют размер (B, 1, H, W), убираем размерность канала
    if masks.dim() == 4 and masks.shape[1] == 1:
        masks = masks.squeeze(1)
        
    pred_masks = model(imgs)
    optim.zero_grad()
    loss, acc = loss_fn(pred_masks, masks)
    loss.backward()
    optim.step()
    return loss.item(), acc.item()

@torch.no_grad()
def validate_batch(model, batch, loss_fn):
    model.eval()
    imgs, masks = batch
    pred_masks = model(imgs)
    loss, acc = loss_fn(pred_masks, masks)
    return loss.item(), acc.item()

# %%
model = UNet(out_channels=2).to(device)
optim = torch.optim.Adam(model.parameters(), lr=5e-4)
loss_fn = loss_fn
n_epochs = 100
log = Report(n_epochs)
for e in range(n_epochs):
    
    N = len(tr_dl)
    for i, batch in enumerate(tr_dl):
        
        loss, acc = train_batch(model, batch, optim, loss_fn)
        log.record(e+(i+1)/N, trn_loss=loss, trn_acc=acc, end='\r')

    N = len(tst_dl)
    for i, batch in enumerate(tst_dl):
        
        loss, acc = validate_batch(model, batch, loss_fn)
        log.record(e+(i+1)/N, val_loss=loss, val_acc=acc, end='\r')
  
    log.report_avgs(e+1)
# Out:
# 0
# EPOCH: 0.029  trn_loss: 0.754  trn_acc: 0.561  (0.61s - 2062.96s remaining)1
# EPOCH: 0.059  trn_loss: 0.705  trn_acc: 0.515  (0.94s - 1598.58s remaining)2
# EPOCH: 0.088  trn_loss: 0.677  trn_acc: 0.575  (1.32s - 1493.38s remaining)3
# EPOCH: 0.118  trn_loss: 0.651  trn_acc: 0.613  (1.71s - 1449.08s remaining)4
# EPOCH: 0.147  trn_loss: 0.605  trn_acc: 0.697  (2.07s - 1408.77s remaining)5
# EPOCH: 0.176  trn_loss: 0.586  trn_acc: 0.693  (2.47s - 1397.61s remaining)6
# EPOCH: 0.206  trn_loss: 0.578  trn_acc: 0.707  (2.84s - 1374.50s remaining)7
# EPOCH: 0.235  trn_loss: 0.538  trn_acc: 0.757  (3.20s - 1357.50s remaining)8
# EPOCH: 0.265  trn_loss: 0.502  trn_acc: 0.802  (3.57s - 1344.57s remaining)9
# EPOCH: 0.294  trn_loss: 0.493  trn_acc: 0.809  (3.94s - 1335.51s remaining)10
# EPOCH: 0.324  trn_loss: 0.505  trn_acc: 0.789  (4.32s - 1332.04s remaining)11
# EPOCH: 0.353  trn_loss: 0.499  trn_acc: 0.738  (4.68s - 1322.58s remaining)12
# EPOCH: 0.382  trn_loss: 0.528  trn_acc: 0.760  (5.04s - 1312.71s remaining)13
# EPOCH: 0.412  trn_loss: 0.501  trn_acc: 0.798  (5.39s - 1303.95s remaining)14
# EPOCH: 0.441  trn_loss: 0.469  trn_acc: 0.816  (5.77s - 1303.08s remaining)15
# EPOCH: 0.471  trn_loss: 0.424  trn_acc: 0.901  (6.14s - 1299.10s remaining)16
# EPOCH: 0.500  trn_loss: 0.413  trn_acc: 0.880  (6.54s - 1301.71s remaining)17
# EPOCH: 0.529  trn_loss: 0.408  trn_acc: 0.860  (6.92s - 1299.67s remaining)18
# EPOCH: 0.559  trn_loss: 0.403  trn_acc: 0.859  (7.29s - 1296.38s remaining)19
# EPOCH: 0.588  trn_loss: 0.408  trn_acc: 0.844  (7.67s - 1295.41s remaining)20
# EPOCH: 0.618  trn_loss: 0.466  trn_acc: 0.800  (8.04s - 1294.17s remaining)21
# EPOCH: 0.647  trn_loss: 0.419  trn_acc: 0.840  (8.44s - 1295.47s remaining)22
# EPOCH: 0.676  trn_loss: 0.438  trn_acc: 0.830  (8.81s - 1293.69s remaining)23
# EPOCH: 0.706  trn_loss: 0.403  trn_acc: 0.845  (9.19s - 1292.44s remaining)24
# EPOCH: 0.735  trn_loss: 0.469  trn_acc: 0.794  (9.58s - 1292.75s remaining)25
# EPOCH: 0.765  trn_loss: 0.528  trn_acc: 0.749  (9.93s - 1288.34s remaining)26
# EPOCH: 0.794  trn_loss: 0.404  trn_acc: 0.882  (10.31s - 1287.84s remaining)27
# EPOCH: 0.824  trn_loss: 0.377  trn_acc: 0.883  (10.71s - 1289.53s remaining)28
# EPOCH: 0.853  trn_loss: 0.363  trn_acc: 0.879  (11.08s - 1287.46s remaining)29
# EPOCH: 0.882  trn_loss: 0.407  trn_acc: 0.841  (11.45s - 1285.74s remaining)30
# EPOCH: 0.912  trn_loss: 0.426  trn_acc: 0.829  (11.80s - 1282.90s remaining)31
# EPOCH: 0.941  trn_loss: 0.352  trn_acc: 0.869  (12.18s - 1282.01s remaining)32
# EPOCH: 0.971  trn_loss: 0.405  trn_acc: 0.858  (12.53s - 1278.40s remaining)33
# EPOCH: 1.000  trn_loss: 0.488  val_loss: 0.449  trn_acc: 0.784  val_acc: 0.802  (13.61s - 1346.94s remaining)
# 0
# EPOCH: 1.029  trn_loss: 0.380  trn_acc: 0.852  (13.98s - 1343.83s remaining)1
# EPOCH: 1.059  trn_loss: 0.307  trn_acc: 0.919  (14.34s - 1339.94s remaining)2
# EPOCH: 1.088  trn_loss: 0.350  trn_acc: 0.889  (14.70s - 1336.23s remaining)3
# EPOCH: 1.118  trn_loss: 0.370  trn_acc: 0.872  (15.05s - 1331.91s remaining)4
# EPOCH: 1.147  trn_loss: 0.361  trn_acc: 0.862  (15.42s - 1328.65s remaining)5
# EPOCH: 1.176  trn_loss: 0.348  trn_acc: 0.874  (15.81s - 1327.89s remaining)6
# EPOCH: 1.206  trn_loss: 0.394  trn_acc: 0.850  (16.15s - 1323.30s remaining)7
# EPOCH: 1.235  trn_loss: 0.355  trn_acc: 0.872  (16.51s - 1319.79s remaining)8
# EPOCH: 1.265  trn_loss: 0.331  trn_acc: 0.878  (16.89s - 1318.61s remaining)9
# EPOCH: 1.294  trn_loss: 0.417  trn_acc: 0.832  (17.25s - 1315.41s remaining)10
# EPOCH: 1.324  trn_loss: 0.338  trn_acc: 0.865  (17.62s - 1313.75s remaining)11
# EPOCH: 1.353  trn_loss: 0.354  trn_acc: 0.856  (18.04s - 1315.06s remaining)12
# EPOCH: 1.382  trn_loss: 0.372  trn_acc: 0.843  (18.46s - 1317.15s remaining)13
# EPOCH: 1.412  trn_loss: 0.387  trn_acc: 0.833  (18.86s - 1316.91s remaining)14
# EPOCH: 1.441  trn_loss: 0.283  trn_acc: 0.911  (19.24s - 1315.70s remaining)15
# EPOCH: 1.471  trn_loss: 0.358  trn_acc: 0.845  (19.63s - 1315.20s remaining)16
# EPOCH: 1.500  trn_loss: 0.323  trn_acc: 0.876  (20.04s - 1316.21s remaining)17
# EPOCH: 1.529  trn_loss: 0.373  trn_acc: 0.843  (20.49s - 1319.22s remaining)18
# EPOCH: 1.559  trn_loss: 0.425  trn_acc: 0.814  (20.90s - 1319.77s remaining)19
# EPOCH: 1.588  trn_loss: 0.336  trn_acc: 0.869  (21.30s - 1320.10s remaining)20
# EPOCH: 1.618  trn_loss: 0.365  trn_acc: 0.849  (21.76s - 1323.56s remaining)21
# EPOCH: 1.647  trn_loss: 0.382  trn_acc: 0.840  (22.18s - 1324.61s remaining)22
# EPOCH: 1.676  trn_loss: 0.368  trn_acc: 0.849  (22.64s - 1327.73s remaining)23
# EPOCH: 1.706  trn_loss: 0.354  trn_acc: 0.855  (23.05s - 1328.01s remaining)24
# EPOCH: 1.735  trn_loss: 0.374  trn_acc: 0.846  (23.46s - 1328.61s remaining)25
# EPOCH: 1.765  trn_loss: 0.254  trn_acc: 0.920  (23.87s - 1328.56s remaining)26
# EPOCH: 1.794  trn_loss: 0.293  trn_acc: 0.892  (24.27s - 1328.45s remaining)27
# EPOCH: 1.824  trn_loss: 0.362  trn_acc: 0.856  (24.66s - 1327.62s remaining)28
# EPOCH: 1.853  trn_loss: 0.320  trn_acc: 0.873  (25.08s - 1328.45s remaining)29
# EPOCH: 1.882  trn_loss: 0.294  trn_acc: 0.899  (25.46s - 1326.90s remaining)30
# EPOCH: 1.912  trn_loss: 0.287  trn_acc: 0.895  (25.86s - 1326.62s remaining)31
# EPOCH: 1.941  trn_loss: 0.332  trn_acc: 0.877  (26.26s - 1326.38s remaining)32
# EPOCH: 1.971  trn_loss: 0.284  trn_acc: 0.915  (26.63s - 1324.69s remaining)33
# EPOCH: 2.000  trn_loss: 0.347  val_loss: 0.402  trn_acc: 0.868  val_acc: 0.823  (27.84s - 1364.20s remaining)
# 0
# EPOCH: 2.029  trn_loss: 0.387  trn_acc: 0.834  (28.24s - 1363.53s remaining)1
# EPOCH: 2.059  trn_loss: 0.358  trn_acc: 0.851  (28.65s - 1362.72s remaining)2
# EPOCH: 2.088  trn_loss: 0.472  trn_acc: 0.800  (29.05s - 1361.88s remaining)3
# EPOCH: 2.118  trn_loss: 0.341  trn_acc: 0.862  (29.43s - 1360.49s remaining)4
# EPOCH: 2.147  trn_loss: 0.321  trn_acc: 0.874  (29.83s - 1359.32s remaining)5
# EPOCH: 2.176  trn_loss: 0.310  trn_acc: 0.880  (30.25s - 1359.42s remaining)6
# EPOCH: 2.206  trn_loss: 0.296  trn_acc: 0.887  (30.68s - 1360.08s remaining)7
# EPOCH: 2.235  trn_loss: 0.323  trn_acc: 0.879  (31.06s - 1358.53s remaining)8
# EPOCH: 2.265  trn_loss: 0.301  trn_acc: 0.885  (31.45s - 1357.10s remaining)9
# EPOCH: 2.294  trn_loss: 0.272  trn_acc: 0.900  (31.84s - 1355.86s remaining)10
# EPOCH: 2.324  trn_loss: 0.367  trn_acc: 0.848  (32.25s - 1355.91s remaining)11
# EPOCH: 2.353  trn_loss: 0.293  trn_acc: 0.885  (32.65s - 1354.99s remaining)12
# EPOCH: 2.382  trn_loss: 0.316  trn_acc: 0.869  (33.05s - 1354.04s remaining)13
# EPOCH: 2.412  trn_loss: 0.329  trn_acc: 0.866  (33.45s - 1353.67s remaining)14
# EPOCH: 2.441  trn_loss: 0.326  trn_acc: 0.868  (33.81s - 1351.31s remaining)15
# EPOCH: 2.471  trn_loss: 0.320  trn_acc: 0.868  (34.20s - 1350.13s remaining)16
# EPOCH: 2.500  trn_loss: 0.279  trn_acc: 0.892  (34.61s - 1349.64s remaining)17
# EPOCH: 2.529  trn_loss: 0.267  trn_acc: 0.904  (34.95s - 1346.95s remaining)18
# EPOCH: 2.559  trn_loss: 0.405  trn_acc: 0.814  (35.33s - 1345.54s remaining)19
# EPOCH: 2.588  trn_loss: 0.245  trn_acc: 0.918  (35.69s - 1343.17s remaining)20
# EPOCH: 2.618  trn_loss: 0.275  trn_acc: 0.904  (36.05s - 1341.10s remaining)21
# EPOCH: 2.647  trn_loss: 0.340  trn_acc: 0.872  (36.39s - 1338.41s remaining)22
# EPOCH: 2.676  trn_loss: 0.339  trn_acc: 0.857  (36.78s - 1337.49s remaining)23
# EPOCH: 2.706  trn_loss: 0.396  trn_acc: 0.834  (37.15s - 1335.89s remaining)24
# EPOCH: 2.735  trn_loss: 0.288  trn_acc: 0.887  (37.55s - 1335.42s remaining)25
# EPOCH: 2.765  trn_loss: 0.305  trn_acc: 0.876  (37.92s - 1333.75s remaining)26
# EPOCH: 2.794  trn_loss: 0.350  trn_acc: 0.870  (38.27s - 1331.42s remaining)27
# EPOCH: 2.824  trn_loss: 0.319  trn_acc: 0.872  (38.65s - 1330.12s remaining)28
# EPOCH: 2.853  trn_loss: 0.304  trn_acc: 0.877  (39.03s - 1328.88s remaining)29
# EPOCH: 2.882  trn_loss: 0.266  trn_acc: 0.901  (39.39s - 1327.05s remaining)30
# EPOCH: 2.912  trn_loss: 0.309  trn_acc: 0.878  (39.75s - 1325.42s remaining)31
# EPOCH: 2.941  trn_loss: 0.218  trn_acc: 0.927  (40.14s - 1324.54s remaining)32
# EPOCH: 2.971  trn_loss: 0.281  trn_acc: 0.892  (40.50s - 1322.88s remaining)33
# EPOCH: 3.000  trn_loss: 0.321  val_loss: 0.357  trn_acc: 0.872  val_acc: 0.841  (41.58s - 1344.33s remaining)
# 0
# EPOCH: 3.029  trn_loss: 0.266  trn_acc: 0.912  (41.94s - 1342.37s remaining)1
# EPOCH: 3.059  trn_loss: 0.272  trn_acc: 0.902  (42.29s - 1340.31s remaining)2
# EPOCH: 3.088  trn_loss: 0.252  trn_acc: 0.904  (42.66s - 1338.66s remaining)3
# EPOCH: 3.118  trn_loss: 0.357  trn_acc: 0.852  (43.03s - 1337.06s remaining)4
# EPOCH: 3.147  trn_loss: 0.367  trn_acc: 0.837  (43.41s - 1336.07s remaining)5
# EPOCH: 3.176  trn_loss: 0.243  trn_acc: 0.914  (43.78s - 1334.54s remaining)6
# EPOCH: 3.206  trn_loss: 0.214  trn_acc: 0.941  (44.12s - 1332.01s remaining)7
# EPOCH: 3.235  trn_loss: 0.364  trn_acc: 0.846  (44.50s - 1330.87s remaining)8
# EPOCH: 3.265  trn_loss: 0.272  trn_acc: 0.897  (44.87s - 1329.64s remaining)9
# EPOCH: 3.294  trn_loss: 0.240  trn_acc: 0.920  (45.24s - 1328.12s remaining)10
# EPOCH: 3.324  trn_loss: 0.237  trn_acc: 0.920  (45.59s - 1326.29s remaining)11
# EPOCH: 3.353  trn_loss: 0.264  trn_acc: 0.898  (45.96s - 1324.86s remaining)12
# EPOCH: 3.382  trn_loss: 0.292  trn_acc: 0.883  (46.31s - 1322.91s remaining)13
# EPOCH: 3.412  trn_loss: 0.312  trn_acc: 0.871  (46.68s - 1321.49s remaining)14
# EPOCH: 3.441  trn_loss: 0.334  trn_acc: 0.864  (47.03s - 1319.62s remaining)15
# EPOCH: 3.471  trn_loss: 0.256  trn_acc: 0.900  (47.39s - 1318.13s remaining)16
# EPOCH: 3.500  trn_loss: 0.304  trn_acc: 0.874  (47.78s - 1317.24s remaining)17
# EPOCH: 3.529  trn_loss: 0.218  trn_acc: 0.927  (48.15s - 1316.01s remaining)18
# EPOCH: 3.559  trn_loss: 0.381  trn_acc: 0.850  (48.49s - 1314.00s remaining)19
# EPOCH: 3.588  trn_loss: 0.295  trn_acc: 0.896  (48.85s - 1312.59s remaining)20
# EPOCH: 3.618  trn_loss: 0.344  trn_acc: 0.857  (49.21s - 1310.97s remaining)21
# EPOCH: 3.647  trn_loss: 0.288  trn_acc: 0.886  (49.57s - 1309.57s remaining)22
# EPOCH: 3.676  trn_loss: 0.406  trn_acc: 0.824  (49.94s - 1308.33s remaining)23
# EPOCH: 3.706  trn_loss: 0.329  trn_acc: 0.855  (50.29s - 1306.86s remaining)24
# EPOCH: 3.735  trn_loss: 0.369  trn_acc: 0.843  (50.68s - 1306.01s remaining)25
# EPOCH: 3.765  trn_loss: 0.372  trn_acc: 0.837  (51.06s - 1305.23s remaining)26
# EPOCH: 3.794  trn_loss: 0.319  trn_acc: 0.867  (51.41s - 1303.67s remaining)27
# EPOCH: 3.824  trn_loss: 0.413  trn_acc: 0.822  (51.77s - 1302.30s remaining)28
# EPOCH: 3.853  trn_loss: 0.400  trn_acc: 0.835  (52.14s - 1300.99s remaining)29
# EPOCH: 3.882  trn_loss: 0.285  trn_acc: 0.894  (52.49s - 1299.48s remaining)30
# EPOCH: 3.912  trn_loss: 0.321  trn_acc: 0.871  (52.87s - 1298.70s remaining)31
# EPOCH: 3.941  trn_loss: 0.363  trn_acc: 0.845  (53.23s - 1297.33s remaining)32
# EPOCH: 3.971  trn_loss: 0.316  trn_acc: 0.863  (53.59s - 1296.13s remaining)33
# EPOCH: 4.000  trn_loss: 0.313  val_loss: 0.388  trn_acc: 0.875  val_acc: 0.831  (54.70s - 1312.85s remaining)
# 0
# EPOCH: 4.029  trn_loss: 0.308  trn_acc: 0.880  (55.06s - 1311.46s remaining)1
# EPOCH: 4.059  trn_loss: 0.248  trn_acc: 0.909  (55.43s - 1310.35s remaining)2
# EPOCH: 4.088  trn_loss: 0.216  trn_acc: 0.927  (55.81s - 1309.30s remaining)3
# EPOCH: 4.118  trn_loss: 0.245  trn_acc: 0.908  (56.14s - 1307.35s remaining)4
# EPOCH: 4.147  trn_loss: 0.339  trn_acc: 0.870  (56.55s - 1306.99s remaining)5
# EPOCH: 4.176  trn_loss: 0.351  trn_acc: 0.859  (56.90s - 1305.60s remaining)6
# EPOCH: 4.206  trn_loss: 0.277  trn_acc: 0.889  (57.34s - 1305.91s remaining)7
# EPOCH: 4.235  trn_loss: 0.288  trn_acc: 0.886  (57.77s - 1306.30s remaining)8
# EPOCH: 4.265  trn_loss: 0.268  trn_acc: 0.894  (58.16s - 1305.63s remaining)9
# EPOCH: 4.294  trn_loss: 0.306  trn_acc: 0.872  (58.58s - 1305.71s remaining)10
# EPOCH: 4.324  trn_loss: 0.373  trn_acc: 0.844  (58.97s - 1304.90s remaining)11
# EPOCH: 4.353  trn_loss: 0.223  trn_acc: 0.915  (59.34s - 1303.82s remaining)12
# EPOCH: 4.382  trn_loss: 0.275  trn_acc: 0.889  (59.74s - 1303.35s remaining)13
# EPOCH: 4.412  trn_loss: 0.444  trn_acc: 0.803  (60.15s - 1303.17s remaining)14
# EPOCH: 4.441  trn_loss: 0.276  trn_acc: 0.890  (60.52s - 1302.10s remaining)15
# EPOCH: 4.471  trn_loss: 0.223  trn_acc: 0.919  (60.93s - 1301.96s remaining)16
# EPOCH: 4.500  trn_loss: 0.334  trn_acc: 0.861  (61.34s - 1301.86s remaining)17
# EPOCH: 4.529  trn_loss: 0.238  trn_acc: 0.916  (61.72s - 1300.87s remaining)18
# EPOCH: 4.559  trn_loss: 0.367  trn_acc: 0.842  (62.08s - 1299.74s remaining)19
# EPOCH: 4.588  trn_loss: 0.447  trn_acc: 0.815  (62.46s - 1298.83s remaining)20
# EPOCH: 4.618  trn_loss: 0.267  trn_acc: 0.891  (62.87s - 1298.63s remaining)21
# EPOCH: 4.647  trn_loss: 0.310  trn_acc: 0.881  (63.23s - 1297.50s remaining)22
# EPOCH: 4.676  trn_loss: 0.260  trn_acc: 0.906  (63.61s - 1296.62s remaining)23
# EPOCH: 4.706  trn_loss: 0.286  trn_acc: 0.886  (63.98s - 1295.57s remaining)24
# EPOCH: 4.735  trn_loss: 0.306  trn_acc: 0.870  (64.37s - 1295.01s remaining)25
# EPOCH: 4.765  trn_loss: 0.281  trn_acc: 0.891  (64.77s - 1294.62s remaining)26
# EPOCH: 4.794  trn_loss: 0.262  trn_acc: 0.897  (65.16s - 1294.08s remaining)27
# EPOCH: 4.824  trn_loss: 0.291  trn_acc: 0.885  (65.57s - 1293.82s remaining)28
# EPOCH: 4.853  trn_loss: 0.282  trn_acc: 0.886  (65.95s - 1293.11s remaining)29
# EPOCH: 4.882  trn_loss: 0.392  trn_acc: 0.836  (66.35s - 1292.56s remaining)30
# EPOCH: 4.912  trn_loss: 0.401  trn_acc: 0.819  (66.76s - 1292.48s remaining)31
# EPOCH: 4.941  trn_loss: 0.367  trn_acc: 0.851  (67.14s - 1291.62s remaining)32
# EPOCH: 4.971  trn_loss: 0.263  trn_acc: 0.894  (67.57s - 1291.80s remaining)33
# EPOCH: 5.000  trn_loss: 0.303  val_loss: 0.333  trn_acc: 0.879  val_acc: 0.858  (68.75s - 1306.24s remaining)
# 0
# EPOCH: 5.029  trn_loss: 0.267  trn_acc: 0.903  (69.12s - 1305.24s remaining)1
# EPOCH: 5.059  trn_loss: 0.368  trn_acc: 0.832  (69.52s - 1304.64s remaining)2
# EPOCH: 5.088  trn_loss: 0.315  trn_acc: 0.869  (69.94s - 1304.57s remaining)3
# EPOCH: 5.118  trn_loss: 0.317  trn_acc: 0.877  (70.36s - 1304.40s remaining)4
# EPOCH: 5.147  trn_loss: 0.244  trn_acc: 0.904  (70.73s - 1303.49s remaining)5
# EPOCH: 5.176  trn_loss: 0.310  trn_acc: 0.869  (71.09s - 1302.24s remaining)6
# EPOCH: 5.206  trn_loss: 0.235  trn_acc: 0.916  (71.48s - 1301.62s remaining)7
# EPOCH: 5.235  trn_loss: 0.274  trn_acc: 0.891  (71.87s - 1300.98s remaining)8
# EPOCH: 5.265  trn_loss: 0.357  trn_acc: 0.859  (72.23s - 1299.68s remaining)9
# EPOCH: 5.294  trn_loss: 0.261  trn_acc: 0.892  (72.61s - 1298.87s remaining)10
# EPOCH: 5.324  trn_loss: 0.282  trn_acc: 0.882  (72.98s - 1298.00s remaining)11
# EPOCH: 5.353  trn_loss: 0.293  trn_acc: 0.881  (73.36s - 1297.13s remaining)12
# EPOCH: 5.382  trn_loss: 0.256  trn_acc: 0.898  (73.73s - 1296.04s remaining)13
# EPOCH: 5.412  trn_loss: 0.238  trn_acc: 0.912  (74.11s - 1295.26s remaining)14
# EPOCH: 5.441  trn_loss: 0.259  trn_acc: 0.896  (74.50s - 1294.67s remaining)15
# EPOCH: 5.471  trn_loss: 0.281  trn_acc: 0.890  (74.85s - 1293.34s remaining)16
# EPOCH: 5.500  trn_loss: 0.235  trn_acc: 0.904  (75.23s - 1292.58s remaining)17
# EPOCH: 5.529  trn_loss: 0.241  trn_acc: 0.906  (75.67s - 1292.91s remaining)18
# EPOCH: 5.559  trn_loss: 0.346  trn_acc: 0.859  (76.10s - 1292.85s remaining)19
# EPOCH: 5.588  trn_loss: 0.206  trn_acc: 0.921  (76.50s - 1292.51s remaining)20
# EPOCH: 5.618  trn_loss: 0.311  trn_acc: 0.875  (76.86s - 1291.39s remaining)21
# EPOCH: 5.647  trn_loss: 0.314  trn_acc: 0.869  (77.30s - 1291.56s remaining)22
# EPOCH: 5.676  trn_loss: 0.290  trn_acc: 0.882  (77.73s - 1291.58s remaining)23
# EPOCH: 5.706  trn_loss: 0.422  trn_acc: 0.811  (78.11s - 1290.90s remaining)24
# EPOCH: 5.735  trn_loss: 0.294  trn_acc: 0.877  (78.52s - 1290.57s remaining)25
# EPOCH: 5.765  trn_loss: 0.298  trn_acc: 0.877  (78.91s - 1289.87s remaining)26
# EPOCH: 5.794  trn_loss: 0.270  trn_acc: 0.892  (79.29s - 1289.19s remaining)27
# EPOCH: 5.824  trn_loss: 0.306  trn_acc: 0.874  (79.67s - 1288.43s remaining)28
# EPOCH: 5.853  trn_loss: 0.340  trn_acc: 0.859  (80.07s - 1287.95s remaining)29
# EPOCH: 5.882  trn_loss: 0.245  trn_acc: 0.905  (80.46s - 1287.30s remaining)30
# EPOCH: 5.912  trn_loss: 0.310  trn_acc: 0.869  (80.82s - 1286.24s remaining)31
# EPOCH: 5.941  trn_loss: 0.268  trn_acc: 0.887  (81.20s - 1285.53s remaining)32
# EPOCH: 5.971  trn_loss: 0.361  trn_acc: 0.847  (81.65s - 1285.93s remaining)33
# EPOCH: 6.000  trn_loss: 0.290  val_loss: 0.378  trn_acc: 0.882  val_acc: 0.830  (82.90s - 1298.84s remaining)
# 0
# EPOCH: 6.029  trn_loss: 0.264  trn_acc: 0.890  (83.32s - 1298.55s remaining)1
# EPOCH: 6.059  trn_loss: 0.297  trn_acc: 0.883  (83.73s - 1298.26s remaining)2
# EPOCH: 6.088  trn_loss: 0.290  trn_acc: 0.884  (84.11s - 1297.42s remaining)3
# EPOCH: 6.118  trn_loss: 0.205  trn_acc: 0.926  (84.52s - 1297.08s remaining)4
# EPOCH: 6.147  trn_loss: 0.291  trn_acc: 0.875  (84.94s - 1296.90s remaining)5
# EPOCH: 6.176  trn_loss: 0.249  trn_acc: 0.903  (85.36s - 1296.68s remaining)6
# EPOCH: 6.206  trn_loss: 0.281  trn_acc: 0.892  (85.80s - 1296.80s remaining)7
# EPOCH: 6.235  trn_loss: 0.363  trn_acc: 0.855  (86.20s - 1296.26s remaining)8
# EPOCH: 6.265  trn_loss: 0.246  trn_acc: 0.901  (86.64s - 1296.29s remaining)9
# EPOCH: 6.294  trn_loss: 0.365  trn_acc: 0.848  (87.01s - 1295.40s remaining)10
# EPOCH: 6.324  trn_loss: 0.265  trn_acc: 0.899  (87.39s - 1294.55s remaining)11
# EPOCH: 6.353  trn_loss: 0.349  trn_acc: 0.851  (87.80s - 1294.30s remaining)12
# EPOCH: 6.382  trn_loss: 0.282  trn_acc: 0.887  (88.19s - 1293.52s remaining)13
# EPOCH: 6.412  trn_loss: 0.349  trn_acc: 0.857  (88.56s - 1292.71s remaining)14
# EPOCH: 6.441  trn_loss: 0.312  trn_acc: 0.867  (88.98s - 1292.42s remaining)15
# EPOCH: 6.471  trn_loss: 0.259  trn_acc: 0.904  (89.37s - 1291.82s remaining)16
# EPOCH: 6.500  trn_loss: 0.239  trn_acc: 0.902  (89.77s - 1291.28s remaining)17
# EPOCH: 6.529  trn_loss: 0.289  trn_acc: 0.881  (90.18s - 1290.97s remaining)18
# EPOCH: 6.559  trn_loss: 0.304  trn_acc: 0.874  (90.56s - 1290.25s remaining)19
# EPOCH: 6.588  trn_loss: 0.304  trn_acc: 0.878  (90.98s - 1289.92s remaining)20
# EPOCH: 6.618  trn_loss: 0.265  trn_acc: 0.896  (91.38s - 1289.53s remaining)21
# EPOCH: 6.647  trn_loss: 0.238  trn_acc: 0.905  (91.79s - 1289.13s remaining)22
# EPOCH: 6.676  trn_loss: 0.252  trn_acc: 0.898  (92.17s - 1288.30s remaining)23
# EPOCH: 6.706  trn_loss: 0.347  trn_acc: 0.854  (92.57s - 1287.81s remaining)24
# EPOCH: 6.735  trn_loss: 0.248  trn_acc: 0.906  (92.95s - 1287.03s remaining)25
# EPOCH: 6.765  trn_loss: 0.259  trn_acc: 0.893  (93.33s - 1286.38s remaining)26
# EPOCH: 6.794  trn_loss: 0.250  trn_acc: 0.898  (93.75s - 1286.09s remaining)27
# EPOCH: 6.824  trn_loss: 0.206  trn_acc: 0.926  (94.14s - 1285.55s remaining)28
# EPOCH: 6.853  trn_loss: 0.336  trn_acc: 0.851  (94.54s - 1284.99s remaining)29
# EPOCH: 6.882  trn_loss: 0.277  trn_acc: 0.888  (94.94s - 1284.56s remaining)30
# EPOCH: 6.912  trn_loss: 0.210  trn_acc: 0.921  (95.35s - 1284.17s remaining)31
# EPOCH: 6.941  trn_loss: 0.269  trn_acc: 0.885  (95.75s - 1283.70s remaining)32
# EPOCH: 6.971  trn_loss: 0.258  trn_acc: 0.894  (96.16s - 1283.39s remaining)33
# EPOCH: 7.000  trn_loss: 0.282  val_loss: 0.324  trn_acc: 0.886  val_acc: 0.856  (97.37s - 1293.63s remaining)
# 0
# EPOCH: 7.029  trn_loss: 0.300  trn_acc: 0.874  (97.80s - 1293.49s remaining)1
# EPOCH: 7.059  trn_loss: 0.216  trn_acc: 0.920  (98.20s - 1292.93s remaining)2
# EPOCH: 7.088  trn_loss: 0.303  trn_acc: 0.875  (98.56s - 1291.90s remaining)3
# EPOCH: 7.118  trn_loss: 0.187  trn_acc: 0.931  (98.94s - 1291.18s remaining)4
# EPOCH: 7.147  trn_loss: 0.284  trn_acc: 0.880  (99.31s - 1290.22s remaining)5
# EPOCH: 7.176  trn_loss: 0.369  trn_acc: 0.844  (99.68s - 1289.25s remaining)6
# EPOCH: 7.206  trn_loss: 0.344  trn_acc: 0.852  (100.04s - 1288.28s remaining)7
# EPOCH: 7.235  trn_loss: 0.389  trn_acc: 0.834  (100.44s - 1287.82s remaining)8
# EPOCH: 7.265  trn_loss: 0.222  trn_acc: 0.916  (100.84s - 1287.28s remaining)9
# EPOCH: 7.294  trn_loss: 0.252  trn_acc: 0.908  (101.24s - 1286.70s remaining)10
# EPOCH: 7.324  trn_loss: 0.237  trn_acc: 0.906  (101.65s - 1286.30s remaining)11
# EPOCH: 7.353  trn_loss: 0.287  trn_acc: 0.879  (102.07s - 1286.08s remaining)12
# EPOCH: 7.382  trn_loss: 0.262  trn_acc: 0.899  (102.47s - 1285.63s remaining)13
# EPOCH: 7.412  trn_loss: 0.246  trn_acc: 0.903  (102.87s - 1285.00s remaining)14
# EPOCH: 7.441  trn_loss: 0.345  trn_acc: 0.851  (103.28s - 1284.67s remaining)15
# EPOCH: 7.471  trn_loss: 0.280  trn_acc: 0.884  (103.69s - 1284.25s remaining)16
# EPOCH: 7.500  trn_loss: 0.357  trn_acc: 0.854  (104.09s - 1283.76s remaining)17
# EPOCH: 7.529  trn_loss: 0.314  trn_acc: 0.868  (104.48s - 1283.11s remaining)18
# EPOCH: 7.559  trn_loss: 0.326  trn_acc: 0.859  (104.88s - 1282.68s remaining)19
# EPOCH: 7.588  trn_loss: 0.398  trn_acc: 0.833  (105.32s - 1282.58s remaining)20
# EPOCH: 7.618  trn_loss: 0.231  trn_acc: 0.910  (105.70s - 1281.85s remaining)21
# EPOCH: 7.647  trn_loss: 0.282  trn_acc: 0.881  (106.11s - 1281.50s remaining)22
# EPOCH: 7.676  trn_loss: 0.221  trn_acc: 0.927  (106.49s - 1280.70s remaining)23
# EPOCH: 7.706  trn_loss: 0.283  trn_acc: 0.885  (106.87s - 1280.02s remaining)24
# EPOCH: 7.735  trn_loss: 0.347  trn_acc: 0.872  (107.23s - 1279.00s remaining)25
# EPOCH: 7.765  trn_loss: 0.233  trn_acc: 0.910  (107.62s - 1278.42s remaining)26
# EPOCH: 7.794  trn_loss: 0.234  trn_acc: 0.910  (108.02s - 1277.90s remaining)27
# EPOCH: 7.824  trn_loss: 0.237  trn_acc: 0.912  (108.42s - 1277.41s remaining)28
# EPOCH: 7.853  trn_loss: 0.218  trn_acc: 0.914  (108.83s - 1277.02s remaining)29
# EPOCH: 7.882  trn_loss: 0.292  trn_acc: 0.875  (109.23s - 1276.49s remaining)30
# EPOCH: 7.912  trn_loss: 0.266  trn_acc: 0.899  (109.60s - 1275.65s remaining)31
# EPOCH: 7.941  trn_loss: 0.300  trn_acc: 0.870  (109.99s - 1275.10s remaining)32
# EPOCH: 7.971  trn_loss: 0.471  trn_acc: 0.795  (110.38s - 1274.45s remaining)33
# EPOCH: 8.000  trn_loss: 0.294  val_loss: 0.334  trn_acc: 0.881  val_acc: 0.854  (111.53s - 1282.65s remaining)
# 0
# EPOCH: 8.029  trn_loss: 0.216  trn_acc: 0.920  (111.96s - 1282.40s remaining)1
# EPOCH: 8.059  trn_loss: 0.336  trn_acc: 0.853  (112.37s - 1282.03s remaining)2
# EPOCH: 8.088  trn_loss: 0.266  trn_acc: 0.893  (112.78s - 1281.57s remaining)3
# EPOCH: 8.118  trn_loss: 0.329  trn_acc: 0.864  (113.17s - 1280.99s remaining)4
# EPOCH: 8.147  trn_loss: 0.303  trn_acc: 0.877  (113.56s - 1280.35s remaining)5
# EPOCH: 8.176  trn_loss: 0.196  trn_acc: 0.932  (113.95s - 1279.68s remaining)6
# EPOCH: 8.206  trn_loss: 0.254  trn_acc: 0.898  (114.35s - 1279.15s remaining)7
# EPOCH: 8.235  trn_loss: 0.305  trn_acc: 0.873  (114.81s - 1279.32s remaining)8
# EPOCH: 8.265  trn_loss: 0.319  trn_acc: 0.866  (115.24s - 1279.08s remaining)9
# EPOCH: 8.294  trn_loss: 0.238  trn_acc: 0.903  (115.65s - 1278.71s remaining)10
# EPOCH: 8.324  trn_loss: 0.235  trn_acc: 0.892  (116.04s - 1278.04s remaining)11
# EPOCH: 8.353  trn_loss: 0.455  trn_acc: 0.808  (116.42s - 1277.36s remaining)12
# EPOCH: 8.382  trn_loss: 0.253  trn_acc: 0.896  (116.83s - 1276.90s remaining)13
# EPOCH: 8.412  trn_loss: 0.274  trn_acc: 0.896  (117.18s - 1275.87s remaining)14
# EPOCH: 8.441  trn_loss: 0.237  trn_acc: 0.908  (117.57s - 1275.21s remaining)15
# EPOCH: 8.471  trn_loss: 0.282  trn_acc: 0.881  (117.99s - 1275.00s remaining)16
# EPOCH: 8.500  trn_loss: 0.253  trn_acc: 0.901  (118.39s - 1274.46s remaining)17
# EPOCH: 8.529  trn_loss: 0.366  trn_acc: 0.844  (118.80s - 1273.99s remaining)18
# EPOCH: 8.559  trn_loss: 0.219  trn_acc: 0.911  (119.20s - 1273.51s remaining)19
# EPOCH: 8.588  trn_loss: 0.296  trn_acc: 0.876  (119.61s - 1273.13s remaining)20
# EPOCH: 8.618  trn_loss: 0.252  trn_acc: 0.900  (120.00s - 1272.49s remaining)21
# EPOCH: 8.647  trn_loss: 0.302  trn_acc: 0.884  (120.40s - 1271.99s remaining)22
# EPOCH: 8.676  trn_loss: 0.247  trn_acc: 0.906  (120.79s - 1271.35s remaining)23
# EPOCH: 8.706  trn_loss: 0.301  trn_acc: 0.871  (121.18s - 1270.80s remaining)24
# EPOCH: 8.735  trn_loss: 0.242  trn_acc: 0.911  (121.56s - 1270.03s remaining)25
# EPOCH: 8.765  trn_loss: 0.337  trn_acc: 0.856  (121.97s - 1269.66s remaining)26
# EPOCH: 8.794  trn_loss: 0.284  trn_acc: 0.883  (122.35s - 1268.90s remaining)27
# EPOCH: 8.824  trn_loss: 0.197  trn_acc: 0.933  (122.74s - 1268.33s remaining)28
# EPOCH: 8.853  trn_loss: 0.294  trn_acc: 0.874  (123.15s - 1267.96s remaining)29
# EPOCH: 8.882  trn_loss: 0.263  trn_acc: 0.903  (123.53s - 1267.22s remaining)30
# EPOCH: 8.912  trn_loss: 0.294  trn_acc: 0.874  (123.94s - 1266.79s remaining)31
# EPOCH: 8.941  trn_loss: 0.283  trn_acc: 0.888  (124.33s - 1266.25s remaining)32
# EPOCH: 8.971  trn_loss: 0.242  trn_acc: 0.908  (124.70s - 1265.39s remaining)33
# EPOCH: 9.000  trn_loss: 0.277  val_loss: 0.360  trn_acc: 0.888  val_acc: 0.842  (125.87s - 1272.72s remaining)
# 0
# EPOCH: 9.029  trn_loss: 0.368  trn_acc: 0.839  (126.27s - 1272.16s remaining)1
# EPOCH: 9.059  trn_loss: 0.232  trn_acc: 0.910  (126.66s - 1271.50s remaining)2
# EPOCH: 9.088  trn_loss: 0.302  trn_acc: 0.868  (127.04s - 1270.79s remaining)3
# EPOCH: 9.118  trn_loss: 0.250  trn_acc: 0.900  (127.45s - 1270.39s remaining)4
# EPOCH: 9.147  trn_loss: 0.249  trn_acc: 0.896  (127.84s - 1269.79s remaining)5
# EPOCH: 9.176  trn_loss: 0.203  trn_acc: 0.931  (128.22s - 1269.02s remaining)6
# EPOCH: 9.206  trn_loss: 0.283  trn_acc: 0.885  (128.61s - 1268.47s remaining)7
# EPOCH: 9.235  trn_loss: 0.416  trn_acc: 0.822  (129.02s - 1267.97s remaining)8
# EPOCH: 9.265  trn_loss: 0.251  trn_acc: 0.906  (129.39s - 1267.25s remaining)9
# EPOCH: 9.294  trn_loss: 0.176  trn_acc: 0.943  (129.78s - 1266.61s remaining)10
# EPOCH: 9.324  trn_loss: 0.325  trn_acc: 0.863  (130.21s - 1266.34s remaining)11
# EPOCH: 9.353  trn_loss: 0.252  trn_acc: 0.896  (130.60s - 1265.72s remaining)12
# EPOCH: 9.382  trn_loss: 0.229  trn_acc: 0.908  (131.01s - 1265.31s remaining)13
# EPOCH: 9.412  trn_loss: 0.345  trn_acc: 0.859  (131.40s - 1264.68s remaining)14
# EPOCH: 9.441  trn_loss: 0.299  trn_acc: 0.877  (131.77s - 1263.89s remaining)15
# EPOCH: 9.471  trn_loss: 0.229  trn_acc: 0.903  (132.16s - 1263.27s remaining)16
# EPOCH: 9.500  trn_loss: 0.218  trn_acc: 0.920  (132.53s - 1262.52s remaining)17
# EPOCH: 9.529  trn_loss: 0.311  trn_acc: 0.870  (132.94s - 1262.07s remaining)18
# EPOCH: 9.559  trn_loss: 0.266  trn_acc: 0.891  (133.34s - 1261.62s remaining)19
# EPOCH: 9.588  trn_loss: 0.275  trn_acc: 0.882  (133.73s - 1261.04s remaining)20
# EPOCH: 9.618  trn_loss: 0.336  trn_acc: 0.864  (134.13s - 1260.48s remaining)21
# EPOCH: 9.647  trn_loss: 0.249  trn_acc: 0.900  (134.56s - 1260.24s remaining)22
# EPOCH: 9.676  trn_loss: 0.296  trn_acc: 0.888  (134.92s - 1259.43s remaining)23
# EPOCH: 9.706  trn_loss: 0.281  trn_acc: 0.884  (135.31s - 1258.77s remaining)24
# EPOCH: 9.735  trn_loss: 0.357  trn_acc: 0.844  (135.70s - 1258.23s remaining)25
# EPOCH: 9.765  trn_loss: 0.203  trn_acc: 0.924  (136.09s - 1257.64s remaining)26
# EPOCH: 9.794  trn_loss: 0.273  trn_acc: 0.887  (136.49s - 1257.08s remaining)27
# EPOCH: 9.824  trn_loss: 0.306  trn_acc: 0.871  (136.92s - 1256.88s remaining)28
# EPOCH: 9.853  trn_loss: 0.227  trn_acc: 0.917  (137.29s - 1256.12s remaining)29
# EPOCH: 9.882  trn_loss: 0.227  trn_acc: 0.907  (137.71s - 1255.75s remaining)30
# EPOCH: 9.912  trn_loss: 0.256  trn_acc: 0.901  (138.10s - 1255.21s remaining)31
# EPOCH: 9.941  trn_loss: 0.321  trn_acc: 0.868  (138.51s - 1254.79s remaining)32
# EPOCH: 9.971  trn_loss: 0.253  trn_acc: 0.896  (138.93s - 1254.45s remaining)33
# EPOCH: 10.000  trn_loss: 0.275  val_loss: 0.316  trn_acc: 0.888  val_acc: 0.861  (140.12s - 1261.04s remaining)
# 0
# EPOCH: 10.029  trn_loss: 0.226  trn_acc: 0.912  (140.52s - 1260.54s remaining)1
# EPOCH: 10.059  trn_loss: 0.296  trn_acc: 0.878  (140.92s - 1260.05s remaining)2
# EPOCH: 10.088  trn_loss: 0.252  trn_acc: 0.895  (141.33s - 1259.61s remaining)3
# EPOCH: 10.118  trn_loss: 0.400  trn_acc: 0.827  (141.75s - 1259.26s remaining)4
# EPOCH: 10.147  trn_loss: 0.338  trn_acc: 0.867  (142.11s - 1258.43s remaining)5
# EPOCH: 10.176  trn_loss: 0.259  trn_acc: 0.888  (142.49s - 1257.70s remaining)6
# EPOCH: 10.206  trn_loss: 0.267  trn_acc: 0.891  (142.89s - 1257.17s remaining)7
# EPOCH: 10.235  trn_loss: 0.304  trn_acc: 0.877  (143.27s - 1256.52s remaining)8
# EPOCH: 10.265  trn_loss: 0.220  trn_acc: 0.914  (143.67s - 1256.01s remaining)9
# EPOCH: 10.294  trn_loss: 0.198  trn_acc: 0.932  (144.05s - 1255.28s remaining)10
# EPOCH: 10.324  trn_loss: 0.226  trn_acc: 0.913  (144.46s - 1254.84s remaining)11
# EPOCH: 10.353  trn_loss: 0.313  trn_acc: 0.865  (144.86s - 1254.32s remaining)12
# EPOCH: 10.382  trn_loss: 0.272  trn_acc: 0.887  (145.25s - 1253.80s remaining)13
# EPOCH: 10.412  trn_loss: 0.290  trn_acc: 0.888  (145.63s - 1253.04s remaining)14
# EPOCH: 10.441  trn_loss: 0.431  trn_acc: 0.818  (146.01s - 1252.39s remaining)15
# EPOCH: 10.471  trn_loss: 0.431  trn_acc: 0.809  (146.40s - 1251.82s remaining)16
# EPOCH: 10.500  trn_loss: 0.275  trn_acc: 0.893  (146.81s - 1251.35s remaining)17
# EPOCH: 10.529  trn_loss: 0.352  trn_acc: 0.851  (147.20s - 1250.77s remaining)18
# EPOCH: 10.559  trn_loss: 0.263  trn_acc: 0.889  (147.61s - 1250.39s remaining)19
# EPOCH: 10.588  trn_loss: 0.213  trn_acc: 0.916  (148.00s - 1249.82s remaining)20
# EPOCH: 10.618  trn_loss: 0.215  trn_acc: 0.921  (148.41s - 1249.33s remaining)21
# EPOCH: 10.647  trn_loss: 0.323  trn_acc: 0.868  (148.83s - 1249.01s remaining)22
# EPOCH: 10.676  trn_loss: 0.209  trn_acc: 0.919  (149.22s - 1248.43s remaining)23
# EPOCH: 10.706  trn_loss: 0.262  trn_acc: 0.892  (149.60s - 1247.80s remaining)24
# EPOCH: 10.735  trn_loss: 0.260  trn_acc: 0.892  (150.05s - 1247.70s remaining)25
# EPOCH: 10.765  trn_loss: 0.265  trn_acc: 0.889  (150.45s - 1247.16s remaining)26
# EPOCH: 10.794  trn_loss: 0.210  trn_acc: 0.920  (150.87s - 1246.85s remaining)27
# EPOCH: 10.824  trn_loss: 0.255  trn_acc: 0.900  (151.34s - 1246.87s remaining)28
# EPOCH: 10.853  trn_loss: 0.186  trn_acc: 0.935  (151.75s - 1246.47s remaining)29
# EPOCH: 10.882  trn_loss: 0.190  trn_acc: 0.931  (152.14s - 1245.92s remaining)30
# EPOCH: 10.912  trn_loss: 0.516  trn_acc: 0.788  (152.56s - 1245.60s remaining)31
# EPOCH: 10.941  trn_loss: 0.249  trn_acc: 0.902  (152.94s - 1244.88s remaining)32
# EPOCH: 10.971  trn_loss: 0.347  trn_acc: 0.849  (153.32s - 1244.27s remaining)33
# EPOCH: 11.000  trn_loss: 0.283  val_loss: 0.323  trn_acc: 0.885  val_acc: 0.860  (154.54s - 1250.38s remaining)
# 0
# EPOCH: 11.029  trn_loss: 0.371  trn_acc: 0.837  (154.98s - 1250.18s remaining)1
# EPOCH: 11.059  trn_loss: 0.260  trn_acc: 0.901  (155.39s - 1249.75s remaining)2
# EPOCH: 11.088  trn_loss: 0.229  trn_acc: 0.909  (155.86s - 1249.76s remaining)3
# EPOCH: 11.118  trn_loss: 0.236  trn_acc: 0.914  (156.27s - 1249.30s remaining)4
# EPOCH: 11.147  trn_loss: 0.236  trn_acc: 0.904  (156.71s - 1249.11s remaining)5
# EPOCH: 11.176  trn_loss: 0.201  trn_acc: 0.924  (157.12s - 1248.73s remaining)6
# EPOCH: 11.206  trn_loss: 0.422  trn_acc: 0.842  (157.53s - 1248.24s remaining)7
# EPOCH: 11.235  trn_loss: 0.335  trn_acc: 0.867  (157.94s - 1247.84s remaining)8
# EPOCH: 11.265  trn_loss: 0.208  trn_acc: 0.919  (158.36s - 1247.47s remaining)9
# EPOCH: 11.294  trn_loss: 0.215  trn_acc: 0.920  (158.76s - 1246.91s remaining)10
# EPOCH: 11.324  trn_loss: 0.252  trn_acc: 0.896  (159.13s - 1246.14s remaining)11
# EPOCH: 11.353  trn_loss: 0.277  trn_acc: 0.885  (159.50s - 1245.40s remaining)12
# EPOCH: 11.382  trn_loss: 0.304  trn_acc: 0.879  (159.86s - 1244.56s remaining)13
# EPOCH: 11.412  trn_loss: 0.364  trn_acc: 0.836  (160.25s - 1244.01s remaining)14
# EPOCH: 11.441  trn_loss: 0.305  trn_acc: 0.869  (160.68s - 1243.73s remaining)15
# EPOCH: 11.471  trn_loss: 0.277  trn_acc: 0.887  (161.03s - 1242.84s remaining)16
# EPOCH: 11.500  trn_loss: 0.196  trn_acc: 0.926  (161.40s - 1242.04s remaining)17
# EPOCH: 11.529  trn_loss: 0.225  trn_acc: 0.913  (161.82s - 1241.73s remaining)18
# EPOCH: 11.559  trn_loss: 0.367  trn_acc: 0.852  (162.21s - 1241.11s remaining)19
# EPOCH: 11.588  trn_loss: 0.269  trn_acc: 0.895  (162.57s - 1240.32s remaining)20
# EPOCH: 11.618  trn_loss: 0.223  trn_acc: 0.917  (163.01s - 1240.10s remaining)21
# EPOCH: 11.647  trn_loss: 0.234  trn_acc: 0.907  (163.44s - 1239.80s remaining)22
# EPOCH: 11.676  trn_loss: 0.191  trn_acc: 0.929  (163.87s - 1239.56s remaining)23
# EPOCH: 11.706  trn_loss: 0.288  trn_acc: 0.883  (164.25s - 1238.89s remaining)24
# EPOCH: 11.735  trn_loss: 0.364  trn_acc: 0.839  (164.65s - 1238.36s remaining)25
# EPOCH: 11.765  trn_loss: 0.227  trn_acc: 0.909  (165.05s - 1237.86s remaining)26
# EPOCH: 11.794  trn_loss: 0.223  trn_acc: 0.911  (165.45s - 1237.37s remaining)27
# EPOCH: 11.824  trn_loss: 0.266  trn_acc: 0.888  (165.91s - 1237.29s remaining)28
# EPOCH: 11.853  trn_loss: 0.304  trn_acc: 0.878  (166.28s - 1236.57s remaining)29
# EPOCH: 11.882  trn_loss: 0.278  trn_acc: 0.889  (166.65s - 1235.85s remaining)30
# EPOCH: 11.912  trn_loss: 0.242  trn_acc: 0.903  (167.08s - 1235.54s remaining)31
# EPOCH: 11.941  trn_loss: 0.273  trn_acc: 0.890  (167.44s - 1234.75s remaining)32
# EPOCH: 11.971  trn_loss: 0.287  trn_acc: 0.875  (167.80s - 1233.99s remaining)33
# EPOCH: 12.000  trn_loss: 0.269  val_loss: 0.317  trn_acc: 0.891  val_acc: 0.861  (168.92s - 1238.73s remaining)
# 0
# EPOCH: 12.029  trn_loss: 0.225  trn_acc: 0.908  (169.28s - 1237.95s remaining)1
# EPOCH: 12.059  trn_loss: 0.278  trn_acc: 0.884  (169.66s - 1237.25s remaining)2
# EPOCH: 12.088  trn_loss: 0.227  trn_acc: 0.910  (170.03s - 1236.56s remaining)3
# EPOCH: 12.118  trn_loss: 0.273  trn_acc: 0.886  (170.45s - 1236.15s remaining)4
# EPOCH: 12.147  trn_loss: 0.284  trn_acc: 0.883  (170.80s - 1235.30s remaining)5
# EPOCH: 12.176  trn_loss: 0.252  trn_acc: 0.898  (171.17s - 1234.56s remaining)6
# EPOCH: 12.206  trn_loss: 0.184  trn_acc: 0.937  (171.59s - 1234.23s remaining)7
# EPOCH: 12.235  trn_loss: 0.274  trn_acc: 0.886  (172.06s - 1234.19s remaining)8
# EPOCH: 12.265  trn_loss: 0.184  trn_acc: 0.937  (172.42s - 1233.37s remaining)9
# EPOCH: 12.294  trn_loss: 0.272  trn_acc: 0.893  (172.87s - 1233.25s remaining)10
# EPOCH: 12.324  trn_loss: 0.266  trn_acc: 0.886  (173.27s - 1232.75s remaining)11
# EPOCH: 12.353  trn_loss: 0.254  trn_acc: 0.896  (173.66s - 1232.16s remaining)12
# EPOCH: 12.382  trn_loss: 0.266  trn_acc: 0.889  (174.05s - 1231.58s remaining)13
# EPOCH: 12.412  trn_loss: 0.240  trn_acc: 0.901  (174.41s - 1230.79s remaining)14
# EPOCH: 12.441  trn_loss: 0.186  trn_acc: 0.928  (174.79s - 1230.11s remaining)15
# EPOCH: 12.471  trn_loss: 0.333  trn_acc: 0.864  (175.15s - 1229.36s remaining)16
# EPOCH: 12.500  trn_loss: 0.225  trn_acc: 0.913  (175.55s - 1228.85s remaining)17
# EPOCH: 12.529  trn_loss: 0.374  trn_acc: 0.840  (175.93s - 1228.24s remaining)18
# EPOCH: 12.559  trn_loss: 0.281  trn_acc: 0.877  (176.31s - 1227.56s remaining)19
# EPOCH: 12.588  trn_loss: 0.354  trn_acc: 0.857  (176.66s - 1226.74s remaining)20
# EPOCH: 12.618  trn_loss: 0.262  trn_acc: 0.898  (177.10s - 1226.49s remaining)21
# EPOCH: 12.647  trn_loss: 0.268  trn_acc: 0.893  (177.47s - 1225.81s remaining)22
# EPOCH: 12.676  trn_loss: 0.285  trn_acc: 0.882  (177.84s - 1225.08s remaining)23
# EPOCH: 12.706  trn_loss: 0.337  trn_acc: 0.858  (178.24s - 1224.58s remaining)24
# EPOCH: 12.735  trn_loss: 0.172  trn_acc: 0.939  (178.61s - 1223.87s remaining)25
# EPOCH: 12.765  trn_loss: 0.276  trn_acc: 0.887  (179.02s - 1223.46s remaining)26
# EPOCH: 12.794  trn_loss: 0.246  trn_acc: 0.910  (179.45s - 1223.15s remaining)27
# EPOCH: 12.824  trn_loss: 0.243  trn_acc: 0.900  (179.81s - 1222.36s remaining)28
# EPOCH: 12.853  trn_loss: 0.269  trn_acc: 0.884  (180.20s - 1221.83s remaining)29
# EPOCH: 12.882  trn_loss: 0.229  trn_acc: 0.906  (180.64s - 1221.62s remaining)30
# EPOCH: 12.912  trn_loss: 0.181  trn_acc: 0.938  (181.02s - 1220.98s remaining)31
# EPOCH: 12.941  trn_loss: 0.273  trn_acc: 0.884  (181.41s - 1220.41s remaining)32
# EPOCH: 12.971  trn_loss: 0.279  trn_acc: 0.884  (181.79s - 1219.76s remaining)33
# EPOCH: 13.000  trn_loss: 0.264  val_loss: 0.327  trn_acc: 0.893  val_acc: 0.859  (182.88s - 1223.87s remaining)
# 0
# EPOCH: 13.029  trn_loss: 0.249  trn_acc: 0.896  (183.27s - 1223.33s remaining)1
# EPOCH: 13.059  trn_loss: 0.325  trn_acc: 0.877  (183.63s - 1222.52s remaining)2
# EPOCH: 13.088  trn_loss: 0.294  trn_acc: 0.878  (184.01s - 1221.89s remaining)3
# EPOCH: 13.118  trn_loss: 0.215  trn_acc: 0.918  (184.38s - 1221.20s remaining)4
# EPOCH: 13.147  trn_loss: 0.243  trn_acc: 0.909  (184.73s - 1220.40s remaining)5
# EPOCH: 13.176  trn_loss: 0.272  trn_acc: 0.885  (185.12s - 1219.83s remaining)6
# EPOCH: 13.206  trn_loss: 0.223  trn_acc: 0.914  (185.48s - 1219.06s remaining)7
# EPOCH: 13.235  trn_loss: 0.266  trn_acc: 0.896  (185.92s - 1218.84s remaining)8
# EPOCH: 13.265  trn_loss: 0.284  trn_acc: 0.882  (186.31s - 1218.22s remaining)9
# EPOCH: 13.294  trn_loss: 0.329  trn_acc: 0.864  (186.75s - 1218.04s remaining)10
# EPOCH: 13.324  trn_loss: 0.253  trn_acc: 0.898  (187.14s - 1217.41s remaining)11
# EPOCH: 13.353  trn_loss: 0.287  trn_acc: 0.884  (187.48s - 1216.54s remaining)12
# EPOCH: 13.382  trn_loss: 0.277  trn_acc: 0.883  (187.91s - 1216.23s remaining)13
# EPOCH: 13.412  trn_loss: 0.249  trn_acc: 0.896  (188.38s - 1216.19s remaining)14
# EPOCH: 13.441  trn_loss: 0.221  trn_acc: 0.914  (188.79s - 1215.76s remaining)15
# EPOCH: 13.471  trn_loss: 0.400  trn_acc: 0.832  (189.19s - 1215.25s remaining)16
# EPOCH: 13.500  trn_loss: 0.220  trn_acc: 0.913  (189.58s - 1214.74s remaining)17
# EPOCH: 13.529  trn_loss: 0.292  trn_acc: 0.880  (189.98s - 1214.20s remaining)18
# EPOCH: 13.559  trn_loss: 0.247  trn_acc: 0.893  (190.37s - 1213.63s remaining)19
# EPOCH: 13.588  trn_loss: 0.190  trn_acc: 0.929  (190.77s - 1213.19s remaining)20
# EPOCH: 13.618  trn_loss: 0.215  trn_acc: 0.913  (191.17s - 1212.68s remaining)21
# EPOCH: 13.647  trn_loss: 0.260  trn_acc: 0.892  (191.60s - 1212.37s remaining)22
# EPOCH: 13.676  trn_loss: 0.200  trn_acc: 0.924  (192.01s - 1211.93s remaining)23
# EPOCH: 13.706  trn_loss: 0.241  trn_acc: 0.897  (192.41s - 1211.43s remaining)24
# EPOCH: 13.735  trn_loss: 0.211  trn_acc: 0.919  (192.81s - 1210.94s remaining)25
# EPOCH: 13.765  trn_loss: 0.287  trn_acc: 0.895  (193.16s - 1210.17s remaining)26
# EPOCH: 13.794  trn_loss: 0.339  trn_acc: 0.849  (193.56s - 1209.65s remaining)27
# EPOCH: 13.824  trn_loss: 0.167  trn_acc: 0.940  (193.96s - 1209.18s remaining)28
# EPOCH: 13.853  trn_loss: 0.229  trn_acc: 0.906  (194.35s - 1208.61s remaining)29
# EPOCH: 13.882  trn_loss: 0.261  trn_acc: 0.887  (194.74s - 1208.07s remaining)30
# EPOCH: 13.912  trn_loss: 0.249  trn_acc: 0.900  (195.14s - 1207.59s remaining)31
# EPOCH: 13.941  trn_loss: 0.284  trn_acc: 0.876  (195.53s - 1207.02s remaining)32
# EPOCH: 13.971  trn_loss: 0.208  trn_acc: 0.918  (195.91s - 1206.41s remaining)33
# EPOCH: 14.000  trn_loss: 0.260  val_loss: 0.279  trn_acc: 0.894  val_acc: 0.879  (197.09s - 1210.69s remaining)
# 0
# EPOCH: 14.029  trn_loss: 0.233  trn_acc: 0.903  (197.52s - 1210.36s remaining)1
# EPOCH: 14.059  trn_loss: 0.271  trn_acc: 0.883  (197.90s - 1209.73s remaining)2
# EPOCH: 14.088  trn_loss: 0.266  trn_acc: 0.892  (198.28s - 1209.14s remaining)3
# EPOCH: 14.118  trn_loss: 0.210  trn_acc: 0.914  (198.68s - 1208.61s remaining)4
# EPOCH: 14.147  trn_loss: 0.316  trn_acc: 0.864  (199.07s - 1208.09s remaining)5
# EPOCH: 14.176  trn_loss: 0.219  trn_acc: 0.917  (199.47s - 1207.56s remaining)6
# EPOCH: 14.206  trn_loss: 0.224  trn_acc: 0.912  (199.85s - 1206.95s remaining)7
# EPOCH: 14.235  trn_loss: 0.203  trn_acc: 0.917  (200.24s - 1206.39s remaining)8
# EPOCH: 14.265  trn_loss: 0.456  trn_acc: 0.814  (200.64s - 1205.91s remaining)9
# EPOCH: 14.294  trn_loss: 0.252  trn_acc: 0.894  (201.03s - 1205.34s remaining)10
# EPOCH: 14.324  trn_loss: 0.237  trn_acc: 0.904  (201.43s - 1204.87s remaining)11
# EPOCH: 14.353  trn_loss: 0.291  trn_acc: 0.875  (201.84s - 1204.44s remaining)12
# EPOCH: 14.382  trn_loss: 0.217  trn_acc: 0.916  (202.24s - 1203.95s remaining)13
# EPOCH: 14.412  trn_loss: 0.256  trn_acc: 0.896  (202.65s - 1203.49s remaining)14
# EPOCH: 14.441  trn_loss: 0.195  trn_acc: 0.924  (203.05s - 1203.00s remaining)15
# EPOCH: 14.471  trn_loss: 0.232  trn_acc: 0.906  (203.46s - 1202.58s remaining)16
# EPOCH: 14.500  trn_loss: 0.182  trn_acc: 0.934  (203.86s - 1202.06s remaining)17
# EPOCH: 14.529  trn_loss: 0.224  trn_acc: 0.914  (204.25s - 1201.49s remaining)18
# EPOCH: 14.559  trn_loss: 0.195  trn_acc: 0.923  (204.64s - 1200.99s remaining)19
# EPOCH: 14.588  trn_loss: 0.311  trn_acc: 0.866  (205.04s - 1200.48s remaining)20
# EPOCH: 14.618  trn_loss: 0.275  trn_acc: 0.878  (205.45s - 1200.02s remaining)21
# EPOCH: 14.647  trn_loss: 0.263  trn_acc: 0.896  (205.84s - 1199.49s remaining)22
# EPOCH: 14.676  trn_loss: 0.304  trn_acc: 0.872  (206.21s - 1198.85s remaining)23
# EPOCH: 14.706  trn_loss: 0.287  trn_acc: 0.893  (206.59s - 1198.22s remaining)24
# EPOCH: 14.735  trn_loss: 0.242  trn_acc: 0.907  (206.95s - 1197.50s remaining)25
# EPOCH: 14.765  trn_loss: 0.287  trn_acc: 0.888  (207.33s - 1196.92s remaining)26
# EPOCH: 14.794  trn_loss: 0.200  trn_acc: 0.922  (207.74s - 1196.48s remaining)27
# EPOCH: 14.824  trn_loss: 0.268  trn_acc: 0.898  (208.10s - 1195.77s remaining)28
# EPOCH: 14.853  trn_loss: 0.452  trn_acc: 0.813  (208.50s - 1195.26s remaining)29
# EPOCH: 14.882  trn_loss: 0.268  trn_acc: 0.888  (208.91s - 1194.85s remaining)30
# EPOCH: 14.912  trn_loss: 0.195  trn_acc: 0.924  (209.31s - 1194.33s remaining)31
# EPOCH: 14.941  trn_loss: 0.238  trn_acc: 0.902  (209.71s - 1193.84s remaining)32
# EPOCH: 14.971  trn_loss: 0.329  trn_acc: 0.860  (210.12s - 1193.42s remaining)33
# EPOCH: 15.000  trn_loss: 0.262  val_loss: 0.331  trn_acc: 0.894  val_acc: 0.855  (211.33s - 1197.52s remaining)
# 0
# EPOCH: 15.029  trn_loss: 0.218  trn_acc: 0.913  (211.74s - 1197.07s remaining)1
# EPOCH: 15.059  trn_loss: 0.264  trn_acc: 0.889  (212.16s - 1196.71s remaining)2
# EPOCH: 15.088  trn_loss: 0.281  trn_acc: 0.882  (212.56s - 1196.19s remaining)3
# EPOCH: 15.118  trn_loss: 0.284  trn_acc: 0.893  (212.92s - 1195.52s remaining)4
# EPOCH: 15.147  trn_loss: 0.283  trn_acc: 0.880  (213.34s - 1195.11s remaining)5
# EPOCH: 15.176  trn_loss: 0.252  trn_acc: 0.894  (213.75s - 1194.69s remaining)6
# EPOCH: 15.206  trn_loss: 0.216  trn_acc: 0.906  (214.15s - 1194.18s remaining)7
# EPOCH: 15.235  trn_loss: 0.312  trn_acc: 0.873  (214.55s - 1193.68s remaining)8
# EPOCH: 15.265  trn_loss: 0.244  trn_acc: 0.912  (214.92s - 1193.02s remaining)9
# EPOCH: 15.294  trn_loss: 0.240  trn_acc: 0.905  (215.30s - 1192.40s remaining)10
# EPOCH: 15.324  trn_loss: 0.247  trn_acc: 0.898  (215.72s - 1192.05s remaining)11
# EPOCH: 15.353  trn_loss: 0.192  trn_acc: 0.929  (216.10s - 1191.47s remaining)12
# EPOCH: 15.382  trn_loss: 0.248  trn_acc: 0.896  (216.53s - 1191.10s remaining)13
# EPOCH: 15.412  trn_loss: 0.236  trn_acc: 0.901  (216.93s - 1190.63s remaining)14
# EPOCH: 15.441  trn_loss: 0.233  trn_acc: 0.913  (217.32s - 1190.11s remaining)15
# EPOCH: 15.471  trn_loss: 0.178  trn_acc: 0.935  (217.72s - 1189.62s remaining)16
# EPOCH: 15.500  trn_loss: 0.179  trn_acc: 0.936  (218.11s - 1189.05s remaining)17
# EPOCH: 15.529  trn_loss: 0.297  trn_acc: 0.882  (218.50s - 1188.49s remaining)18
# EPOCH: 15.559  trn_loss: 0.193  trn_acc: 0.924  (218.90s - 1188.02s remaining)19
# EPOCH: 15.588  trn_loss: 0.288  trn_acc: 0.879  (219.29s - 1187.49s remaining)20
# EPOCH: 15.618  trn_loss: 0.307  trn_acc: 0.873  (219.69s - 1187.01s remaining)21
# EPOCH: 15.647  trn_loss: 0.179  trn_acc: 0.932  (220.10s - 1186.57s remaining)22
# EPOCH: 15.676  trn_loss: 0.306  trn_acc: 0.871  (220.52s - 1186.20s remaining)23
# EPOCH: 15.706  trn_loss: 0.285  trn_acc: 0.880  (220.92s - 1185.67s remaining)24
# EPOCH: 15.735  trn_loss: 0.272  trn_acc: 0.888  (221.31s - 1185.12s remaining)25
# EPOCH: 15.765  trn_loss: 0.381  trn_acc: 0.831  (221.73s - 1184.75s remaining)26
# EPOCH: 15.794  trn_loss: 0.163  trn_acc: 0.937  (222.12s - 1184.24s remaining)27
# EPOCH: 15.824  trn_loss: 0.245  trn_acc: 0.893  (222.52s - 1183.75s remaining)28
# EPOCH: 15.853  trn_loss: 0.254  trn_acc: 0.891  (222.93s - 1183.29s remaining)29
# EPOCH: 15.882  trn_loss: 0.218  trn_acc: 0.914  (223.33s - 1182.81s remaining)30
# EPOCH: 15.912  trn_loss: 0.277  trn_acc: 0.886  (223.71s - 1182.25s remaining)31
# EPOCH: 15.941  trn_loss: 0.408  trn_acc: 0.838  (224.10s - 1181.69s remaining)32
# EPOCH: 15.971  trn_loss: 0.315  trn_acc: 0.869  (224.47s - 1181.07s remaining)33
# EPOCH: 16.000  trn_loss: 0.256  val_loss: 0.279  trn_acc: 0.896  val_acc: 0.881  (225.63s - 1184.55s remaining)
# 0
# EPOCH: 16.029  trn_loss: 0.223  trn_acc: 0.915  (226.01s - 1183.98s remaining)1
# EPOCH: 16.059  trn_loss: 0.225  trn_acc: 0.906  (226.40s - 1183.39s remaining)2
# EPOCH: 16.088  trn_loss: 0.290  trn_acc: 0.880  (226.81s - 1182.97s remaining)3
# EPOCH: 16.118  trn_loss: 0.335  trn_acc: 0.858  (227.20s - 1182.43s remaining)4
# EPOCH: 16.147  trn_loss: 0.261  trn_acc: 0.889  (227.62s - 1182.03s remaining)5
# EPOCH: 16.176  trn_loss: 0.247  trn_acc: 0.900  (228.00s - 1181.48s remaining)6
# EPOCH: 16.206  trn_loss: 0.232  trn_acc: 0.899  (228.40s - 1180.94s remaining)7
# EPOCH: 16.235  trn_loss: 0.257  trn_acc: 0.891  (228.81s - 1180.52s remaining)8
# EPOCH: 16.265  trn_loss: 0.232  trn_acc: 0.903  (229.20s - 1179.97s remaining)9
# EPOCH: 16.294  trn_loss: 0.228  trn_acc: 0.906  (229.58s - 1179.40s remaining)10
# EPOCH: 16.324  trn_loss: 0.220  trn_acc: 0.923  (229.97s - 1178.83s remaining)11
# EPOCH: 16.353  trn_loss: 0.277  trn_acc: 0.879  (230.37s - 1178.36s remaining)12
# EPOCH: 16.382  trn_loss: 0.343  trn_acc: 0.854  (230.75s - 1177.78s remaining)13
# EPOCH: 16.412  trn_loss: 0.229  trn_acc: 0.917  (231.14s - 1177.23s remaining)14
# EPOCH: 16.441  trn_loss: 0.198  trn_acc: 0.922  (231.52s - 1176.64s remaining)15
# EPOCH: 16.471  trn_loss: 0.241  trn_acc: 0.899  (231.93s - 1176.24s remaining)16
# EPOCH: 16.500  trn_loss: 0.189  trn_acc: 0.931  (232.32s - 1175.67s remaining)17
# EPOCH: 16.529  trn_loss: 0.283  trn_acc: 0.884  (232.69s - 1175.05s remaining)18
# EPOCH: 16.559  trn_loss: 0.241  trn_acc: 0.907  (233.07s - 1174.44s remaining)19
# EPOCH: 16.588  trn_loss: 0.265  trn_acc: 0.886  (233.46s - 1173.91s remaining)20
# EPOCH: 16.618  trn_loss: 0.234  trn_acc: 0.904  (233.84s - 1173.34s remaining)21
# EPOCH: 16.647  trn_loss: 0.254  trn_acc: 0.897  (234.25s - 1172.93s remaining)22
# EPOCH: 16.676  trn_loss: 0.217  trn_acc: 0.912  (234.68s - 1172.58s remaining)23
# EPOCH: 16.706  trn_loss: 0.187  trn_acc: 0.926  (235.10s - 1172.17s remaining)24
# EPOCH: 16.735  trn_loss: 0.244  trn_acc: 0.905  (235.48s - 1171.62s remaining)25
# EPOCH: 16.765  trn_loss: 0.211  trn_acc: 0.914  (235.89s - 1171.17s remaining)26
# EPOCH: 16.794  trn_loss: 0.209  trn_acc: 0.917  (236.30s - 1170.74s remaining)27
# EPOCH: 16.824  trn_loss: 0.226  trn_acc: 0.916  (236.66s - 1170.06s remaining)28
# EPOCH: 16.853  trn_loss: 0.297  trn_acc: 0.878  (237.06s - 1169.57s remaining)29
# EPOCH: 16.882  trn_loss: 0.367  trn_acc: 0.843  (237.46s - 1169.10s remaining)30
# EPOCH: 16.912  trn_loss: 0.191  trn_acc: 0.923  (237.87s - 1168.66s remaining)31
# EPOCH: 16.941  trn_loss: 0.301  trn_acc: 0.874  (238.26s - 1168.14s remaining)32
# EPOCH: 16.971  trn_loss: 0.264  trn_acc: 0.895  (238.67s - 1167.72s remaining)33
# EPOCH: 17.000  trn_loss: 0.248  val_loss: 0.315  trn_acc: 0.899  val_acc: 0.862  (239.86s - 1171.06s remaining)
# 0
# EPOCH: 17.029  trn_loss: 0.210  trn_acc: 0.921  (240.27s - 1170.63s remaining)1
# EPOCH: 17.059  trn_loss: 0.192  trn_acc: 0.927  (240.68s - 1170.18s remaining)2
# EPOCH: 17.088  trn_loss: 0.223  trn_acc: 0.907  (241.09s - 1169.75s remaining)3
# EPOCH: 17.118  trn_loss: 0.288  trn_acc: 0.884  (241.48s - 1169.23s remaining)4
# EPOCH: 17.147  trn_loss: 0.238  trn_acc: 0.905  (241.86s - 1168.65s remaining)5
# EPOCH: 17.176  trn_loss: 0.204  trn_acc: 0.919  (242.26s - 1168.17s remaining)6
# EPOCH: 17.206  trn_loss: 0.207  trn_acc: 0.917  (242.64s - 1167.56s remaining)7
# EPOCH: 17.235  trn_loss: 0.278  trn_acc: 0.880  (243.03s - 1167.05s remaining)8
# EPOCH: 17.265  trn_loss: 0.197  trn_acc: 0.920  (243.43s - 1166.55s remaining)9
# EPOCH: 17.294  trn_loss: 0.308  trn_acc: 0.863  (243.81s - 1165.97s remaining)10
# EPOCH: 17.324  trn_loss: 0.203  trn_acc: 0.924  (244.19s - 1165.40s remaining)11
# EPOCH: 17.353  trn_loss: 0.245  trn_acc: 0.899  (244.58s - 1164.89s remaining)12
# EPOCH: 17.382  trn_loss: 0.387  trn_acc: 0.849  (244.97s - 1164.31s remaining)13
# EPOCH: 17.412  trn_loss: 0.212  trn_acc: 0.914  (245.39s - 1163.95s remaining)14
# EPOCH: 17.441  trn_loss: 0.293  trn_acc: 0.884  (245.76s - 1163.33s remaining)15
# EPOCH: 17.471  trn_loss: 0.288  trn_acc: 0.882  (246.14s - 1162.75s remaining)16
# EPOCH: 17.500  trn_loss: 0.228  trn_acc: 0.904  (246.54s - 1162.26s remaining)17
# ...
# EPOCH: 94.206  trn_loss: 0.153  trn_acc: 0.939  (1343.96s - 82.66s remaining)7
# EPOCH: 94.235  trn_loss: 0.144  trn_acc: 0.939  (1344.35s - 82.24s remaining)8
# EPOCH: 94.265  trn_loss: 0.112  trn_acc: 0.954  (1344.74s - 81.82s remaining)9
# EPOCH: 94.294  trn_loss: 0.200  trn_acc: 0.919  (1345.10s - 81.39s remaining)10
# EPOCH: 94.324  trn_loss: 0.141  trn_acc: 0.941  (1345.50s - 80.97s remaining)11
# EPOCH: 94.353  trn_loss: 0.123  trn_acc: 0.950  (1345.88s - 80.55s remaining)12
# EPOCH: 94.382  trn_loss: 0.127  trn_acc: 0.954  (1346.24s - 80.13s remaining)13
# EPOCH: 94.412  trn_loss: 0.211  trn_acc: 0.913  (1346.60s - 79.71s remaining)14
# EPOCH: 94.441  trn_loss: 0.129  trn_acc: 0.947  (1346.98s - 79.28s remaining)15
# EPOCH: 94.471  trn_loss: 0.130  trn_acc: 0.946  (1347.37s - 78.86s remaining)16
# EPOCH: 94.500  trn_loss: 0.109  trn_acc: 0.957  (1347.79s - 78.44s remaining)17
# EPOCH: 94.529  trn_loss: 0.199  trn_acc: 0.916  (1348.20s - 78.02s remaining)18
# EPOCH: 94.559  trn_loss: 0.228  trn_acc: 0.906  (1348.58s - 77.60s remaining)19
# EPOCH: 94.588  trn_loss: 0.164  trn_acc: 0.934  (1348.95s - 77.18s remaining)20
# EPOCH: 94.618  trn_loss: 0.159  trn_acc: 0.941  (1349.35s - 76.76s remaining)21
# EPOCH: 94.647  trn_loss: 0.171  trn_acc: 0.934  (1349.72s - 76.34s remaining)22
# EPOCH: 94.676  trn_loss: 0.151  trn_acc: 0.938  (1350.12s - 75.92s remaining)23
# EPOCH: 94.706  trn_loss: 0.214  trn_acc: 0.907  (1350.48s - 75.49s remaining)24
# EPOCH: 94.735  trn_loss: 0.203  trn_acc: 0.924  (1350.88s - 75.07s remaining)25
# EPOCH: 94.765  trn_loss: 0.122  trn_acc: 0.948  (1351.31s - 74.65s remaining)26
# EPOCH: 94.794  trn_loss: 0.219  trn_acc: 0.910  (1351.74s - 74.23s remaining)27
# EPOCH: 94.824  trn_loss: 0.228  trn_acc: 0.907  (1352.11s - 73.81s remaining)28
# EPOCH: 94.853  trn_loss: 0.097  trn_acc: 0.961  (1352.48s - 73.39s remaining)29
# EPOCH: 94.882  trn_loss: 0.171  trn_acc: 0.931  (1352.83s - 72.97s remaining)30
# EPOCH: 94.912  trn_loss: 0.126  trn_acc: 0.951  (1353.20s - 72.55s remaining)31
# EPOCH: 94.941  trn_loss: 0.119  trn_acc: 0.951  (1353.59s - 72.12s remaining)32
# EPOCH: 94.971  trn_loss: 0.162  trn_acc: 0.932  (1354.01s - 71.71s remaining)33
# EPOCH: 95.000  trn_loss: 0.159  val_loss: 0.286  trn_acc: 0.936  val_acc: 0.891  (1355.20s - 71.33s remaining)
# 0
# EPOCH: 95.029  trn_loss: 0.125  trn_acc: 0.949  (1355.66s - 70.91s remaining)1
# EPOCH: 95.059  trn_loss: 0.156  trn_acc: 0.935  (1356.09s - 70.49s remaining)2
# EPOCH: 95.088  trn_loss: 0.160  trn_acc: 0.932  (1356.53s - 70.07s remaining)3
# EPOCH: 95.118  trn_loss: 0.174  trn_acc: 0.931  (1356.93s - 69.65s remaining)4
# EPOCH: 95.147  trn_loss: 0.176  trn_acc: 0.928  (1357.33s - 69.23s remaining)5
# EPOCH: 95.176  trn_loss: 0.147  trn_acc: 0.943  (1357.75s - 68.81s remaining)6
# EPOCH: 95.206  trn_loss: 0.169  trn_acc: 0.937  (1358.14s - 68.39s remaining)7
# EPOCH: 95.235  trn_loss: 0.219  trn_acc: 0.909  (1358.52s - 67.97s remaining)8
# EPOCH: 95.265  trn_loss: 0.147  trn_acc: 0.938  (1358.95s - 67.55s remaining)9
# EPOCH: 95.294  trn_loss: 0.227  trn_acc: 0.904  (1359.34s - 67.13s remaining)10
# EPOCH: 95.324  trn_loss: 0.187  trn_acc: 0.932  (1359.71s - 66.71s remaining)11
# EPOCH: 95.353  trn_loss: 0.142  trn_acc: 0.943  (1360.11s - 66.29s remaining)12
# EPOCH: 95.382  trn_loss: 0.228  trn_acc: 0.907  (1360.51s - 65.86s remaining)13
# EPOCH: 95.412  trn_loss: 0.087  trn_acc: 0.965  (1360.91s - 65.44s remaining)14
# EPOCH: 95.441  trn_loss: 0.142  trn_acc: 0.946  (1361.31s - 65.02s remaining)15
# EPOCH: 95.471  trn_loss: 0.141  trn_acc: 0.942  (1361.78s - 64.61s remaining)16
# EPOCH: 95.500  trn_loss: 0.148  trn_acc: 0.944  (1362.18s - 64.19s remaining)17
# EPOCH: 95.529  trn_loss: 0.126  trn_acc: 0.948  (1362.56s - 63.77s remaining)18
# EPOCH: 95.559  trn_loss: 0.180  trn_acc: 0.926  (1362.93s - 63.34s remaining)19
# EPOCH: 95.588  trn_loss: 0.170  trn_acc: 0.928  (1363.29s - 62.92s remaining)20
# EPOCH: 95.618  trn_loss: 0.173  trn_acc: 0.928  (1363.68s - 62.50s remaining)21
# EPOCH: 95.647  trn_loss: 0.157  trn_acc: 0.936  (1364.05s - 62.08s remaining)22
# EPOCH: 95.676  trn_loss: 0.116  trn_acc: 0.952  (1364.43s - 61.66s remaining)23
# EPOCH: 95.706  trn_loss: 0.137  trn_acc: 0.943  (1364.80s - 61.24s remaining)24
# EPOCH: 95.735  trn_loss: 0.124  trn_acc: 0.952  (1365.15s - 60.81s remaining)25
# EPOCH: 95.765  trn_loss: 0.134  trn_acc: 0.947  (1365.52s - 60.39s remaining)26
# EPOCH: 95.794  trn_loss: 0.207  trn_acc: 0.915  (1365.88s - 59.97s remaining)27
# EPOCH: 95.824  trn_loss: 0.149  trn_acc: 0.938  (1366.26s - 59.55s remaining)28
# EPOCH: 95.853  trn_loss: 0.125  trn_acc: 0.949  (1366.65s - 59.13s remaining)29
# EPOCH: 95.882  trn_loss: 0.132  trn_acc: 0.954  (1367.00s - 58.71s remaining)30
# EPOCH: 95.912  trn_loss: 0.137  trn_acc: 0.944  (1367.36s - 58.28s remaining)31
# EPOCH: 95.941  trn_loss: 0.134  trn_acc: 0.948  (1367.72s - 57.86s remaining)32
# EPOCH: 95.971  trn_loss: 0.171  trn_acc: 0.928  (1368.08s - 57.44s remaining)33
# EPOCH: 96.000  trn_loss: 0.155  val_loss: 0.288  trn_acc: 0.937  val_acc: 0.895  (1369.20s - 57.05s remaining)
# 0
# EPOCH: 96.029  trn_loss: 0.205  trn_acc: 0.920  (1369.59s - 56.63s remaining)1
# EPOCH: 96.059  trn_loss: 0.161  trn_acc: 0.932  (1369.97s - 56.21s remaining)2
# EPOCH: 96.088  trn_loss: 0.135  trn_acc: 0.950  (1370.33s - 55.79s remaining)3
# EPOCH: 96.118  trn_loss: 0.091  trn_acc: 0.963  (1370.70s - 55.36s remaining)4
# EPOCH: 96.147  trn_loss: 0.208  trn_acc: 0.914  (1371.04s - 54.94s remaining)5
# EPOCH: 96.176  trn_loss: 0.126  trn_acc: 0.948  (1371.40s - 54.52s remaining)6
# EPOCH: 96.206  trn_loss: 0.154  trn_acc: 0.934  (1371.78s - 54.10s remaining)7
# EPOCH: 96.235  trn_loss: 0.192  trn_acc: 0.924  (1372.13s - 53.68s remaining)8
# EPOCH: 96.265  trn_loss: 0.122  trn_acc: 0.950  (1372.51s - 53.26s remaining)9
# EPOCH: 96.294  trn_loss: 0.144  trn_acc: 0.941  (1372.88s - 52.84s remaining)10
# EPOCH: 96.324  trn_loss: 0.159  trn_acc: 0.936  (1373.22s - 52.41s remaining)11
# EPOCH: 96.353  trn_loss: 0.127  trn_acc: 0.947  (1373.60s - 51.99s remaining)12
# EPOCH: 96.382  trn_loss: 0.119  trn_acc: 0.951  (1373.97s - 51.57s remaining)13
# EPOCH: 96.412  trn_loss: 0.123  trn_acc: 0.953  (1374.32s - 51.15s remaining)14
# EPOCH: 96.441  trn_loss: 0.140  trn_acc: 0.943  (1374.68s - 50.73s remaining)15
# EPOCH: 96.471  trn_loss: 0.111  trn_acc: 0.953  (1375.05s - 50.31s remaining)16
# EPOCH: 96.500  trn_loss: 0.169  trn_acc: 0.933  (1375.39s - 49.88s remaining)17
# EPOCH: 96.529  trn_loss: 0.142  trn_acc: 0.940  (1375.77s - 49.46s remaining)18
# EPOCH: 96.559  trn_loss: 0.201  trn_acc: 0.914  (1376.13s - 49.04s remaining)19
# EPOCH: 96.588  trn_loss: 0.147  trn_acc: 0.939  (1376.48s - 48.62s remaining)20
# EPOCH: 96.618  trn_loss: 0.114  trn_acc: 0.954  (1376.85s - 48.20s remaining)21
# EPOCH: 96.647  trn_loss: 0.163  trn_acc: 0.940  (1377.20s - 47.78s remaining)22
# EPOCH: 96.676  trn_loss: 0.126  trn_acc: 0.952  (1377.58s - 47.36s remaining)23
# EPOCH: 96.706  trn_loss: 0.144  trn_acc: 0.939  (1377.95s - 46.94s remaining)24
# EPOCH: 96.735  trn_loss: 0.231  trn_acc: 0.903  (1378.30s - 46.52s remaining)25
# EPOCH: 96.765  trn_loss: 0.215  trn_acc: 0.917  (1378.61s - 46.09s remaining)26
# EPOCH: 96.794  trn_loss: 0.191  trn_acc: 0.920  (1378.99s - 45.67s remaining)27
# EPOCH: 96.824  trn_loss: 0.192  trn_acc: 0.927  (1379.33s - 45.25s remaining)28
# EPOCH: 96.853  trn_loss: 0.197  trn_acc: 0.920  (1379.69s - 44.83s remaining)29
# EPOCH: 96.882  trn_loss: 0.256  trn_acc: 0.890  (1380.05s - 44.41s remaining)30
# EPOCH: 96.912  trn_loss: 0.115  trn_acc: 0.953  (1380.42s - 43.99s remaining)31
# EPOCH: 96.941  trn_loss: 0.087  trn_acc: 0.965  (1380.77s - 43.57s remaining)32
# EPOCH: 96.971  trn_loss: 0.090  trn_acc: 0.964  (1381.14s - 43.15s remaining)33
# EPOCH: 97.000  trn_loss: 0.153  val_loss: 0.314  trn_acc: 0.938  val_acc: 0.895  (1382.26s - 42.75s remaining)
# 0
# EPOCH: 97.029  trn_loss: 0.181  trn_acc: 0.926  (1382.64s - 42.33s remaining)1
# EPOCH: 97.059  trn_loss: 0.167  trn_acc: 0.936  (1383.02s - 41.91s remaining)2
# EPOCH: 97.088  trn_loss: 0.133  trn_acc: 0.944  (1383.39s - 41.49s remaining)3
# EPOCH: 97.118  trn_loss: 0.191  trn_acc: 0.930  (1383.74s - 41.07s remaining)4
# EPOCH: 97.147  trn_loss: 0.106  trn_acc: 0.956  (1384.11s - 40.65s remaining)5
# EPOCH: 97.176  trn_loss: 0.093  trn_acc: 0.963  (1384.47s - 40.23s remaining)6
# EPOCH: 97.206  trn_loss: 0.155  trn_acc: 0.940  (1384.83s - 39.81s remaining)7
# EPOCH: 97.235  trn_loss: 0.138  trn_acc: 0.945  (1385.18s - 39.38s remaining)8
# EPOCH: 97.265  trn_loss: 0.240  trn_acc: 0.898  (1385.55s - 38.96s remaining)9
# EPOCH: 97.294  trn_loss: 0.153  trn_acc: 0.937  (1385.92s - 38.54s remaining)10
# EPOCH: 97.324  trn_loss: 0.127  trn_acc: 0.947  (1386.29s - 38.12s remaining)11
# EPOCH: 97.353  trn_loss: 0.167  trn_acc: 0.928  (1386.65s - 37.70s remaining)12
# EPOCH: 97.382  trn_loss: 0.130  trn_acc: 0.946  (1387.02s - 37.28s remaining)13
# EPOCH: 97.412  trn_loss: 0.176  trn_acc: 0.926  (1387.39s - 36.86s remaining)14
# EPOCH: 97.441  trn_loss: 0.197  trn_acc: 0.916  (1387.74s - 36.44s remaining)15
# EPOCH: 97.471  trn_loss: 0.173  trn_acc: 0.927  (1388.11s - 36.02s remaining)16
# EPOCH: 97.500  trn_loss: 0.103  trn_acc: 0.960  (1388.45s - 35.60s remaining)17
# EPOCH: 97.529  trn_loss: 0.226  trn_acc: 0.917  (1388.77s - 35.18s remaining)18
# EPOCH: 97.559  trn_loss: 0.123  trn_acc: 0.949  (1389.14s - 34.76s remaining)19
# EPOCH: 97.588  trn_loss: 0.173  trn_acc: 0.924  (1389.48s - 34.34s remaining)20
# EPOCH: 97.618  trn_loss: 0.211  trn_acc: 0.916  (1389.85s - 33.92s remaining)21
# EPOCH: 97.647  trn_loss: 0.181  trn_acc: 0.923  (1390.19s - 33.50s remaining)22
# EPOCH: 97.676  trn_loss: 0.159  trn_acc: 0.945  (1390.54s - 33.08s remaining)23
# EPOCH: 97.706  trn_loss: 0.094  trn_acc: 0.962  (1390.90s - 32.66s remaining)24
# EPOCH: 97.735  trn_loss: 0.131  trn_acc: 0.945  (1391.27s - 32.24s remaining)25
# EPOCH: 97.765  trn_loss: 0.104  trn_acc: 0.958  (1391.62s - 31.82s remaining)26
# EPOCH: 97.794  trn_loss: 0.155  trn_acc: 0.937  (1391.97s - 31.40s remaining)27
# EPOCH: 97.824  trn_loss: 0.167  trn_acc: 0.930  (1392.33s - 30.98s remaining)28
# EPOCH: 97.853  trn_loss: 0.158  trn_acc: 0.938  (1392.69s - 30.56s remaining)29
# EPOCH: 97.882  trn_loss: 0.176  trn_acc: 0.929  (1393.03s - 30.14s remaining)30
# EPOCH: 97.912  trn_loss: 0.130  trn_acc: 0.946  (1393.40s - 29.72s remaining)31
# EPOCH: 97.941  trn_loss: 0.096  trn_acc: 0.961  (1393.75s - 29.30s remaining)32
# EPOCH: 97.971  trn_loss: 0.127  trn_acc: 0.946  (1394.12s - 28.88s remaining)33
# EPOCH: 98.000  trn_loss: 0.151  val_loss: 0.285  trn_acc: 0.939  val_acc: 0.888  (1395.24s - 28.47s remaining)
# 0
# EPOCH: 98.029  trn_loss: 0.229  trn_acc: 0.907  (1395.61s - 28.05s remaining)1
# EPOCH: 98.059  trn_loss: 0.165  trn_acc: 0.938  (1395.97s - 27.63s remaining)2
# EPOCH: 98.088  trn_loss: 0.257  trn_acc: 0.892  (1396.32s - 27.21s remaining)3
# EPOCH: 98.118  trn_loss: 0.148  trn_acc: 0.949  (1396.67s - 26.79s remaining)4
# EPOCH: 98.147  trn_loss: 0.184  trn_acc: 0.922  (1397.02s - 26.37s remaining)5
# EPOCH: 98.176  trn_loss: 0.138  trn_acc: 0.943  (1397.40s - 25.96s remaining)6
# EPOCH: 98.206  trn_loss: 0.162  trn_acc: 0.931  (1397.77s - 25.54s remaining)7
# EPOCH: 98.235  trn_loss: 0.139  trn_acc: 0.943  (1398.14s - 25.12s remaining)8
# EPOCH: 98.265  trn_loss: 0.156  trn_acc: 0.935  (1398.52s - 24.70s remaining)9
# EPOCH: 98.294  trn_loss: 0.173  trn_acc: 0.934  (1398.90s - 24.28s remaining)10
# EPOCH: 98.324  trn_loss: 0.186  trn_acc: 0.923  (1399.25s - 23.86s remaining)11
# EPOCH: 98.353  trn_loss: 0.239  trn_acc: 0.898  (1399.61s - 23.44s remaining)12
# EPOCH: 98.382  trn_loss: 0.094  trn_acc: 0.962  (1399.98s - 23.02s remaining)13
# EPOCH: 98.412  trn_loss: 0.087  trn_acc: 0.968  (1400.32s - 22.60s remaining)14
# EPOCH: 98.441  trn_loss: 0.156  trn_acc: 0.934  (1400.69s - 22.18s remaining)15
# EPOCH: 98.471  trn_loss: 0.150  trn_acc: 0.946  (1401.05s - 21.76s remaining)16
# EPOCH: 98.500  trn_loss: 0.090  trn_acc: 0.965  (1401.42s - 21.34s remaining)17
# EPOCH: 98.529  trn_loss: 0.121  trn_acc: 0.950  (1401.80s - 20.92s remaining)18
# EPOCH: 98.559  trn_loss: 0.137  trn_acc: 0.943  (1402.22s - 20.50s remaining)19
# EPOCH: 98.588  trn_loss: 0.211  trn_acc: 0.917  (1402.57s - 20.08s remaining)20
# EPOCH: 98.618  trn_loss: 0.129  trn_acc: 0.952  (1402.91s - 19.67s remaining)21
# EPOCH: 98.647  trn_loss: 0.198  trn_acc: 0.919  (1403.28s - 19.25s remaining)22
# EPOCH: 98.676  trn_loss: 0.180  trn_acc: 0.924  (1403.68s - 18.83s remaining)23
# EPOCH: 98.706  trn_loss: 0.118  trn_acc: 0.952  (1404.05s - 18.41s remaining)24
# EPOCH: 98.735  trn_loss: 0.216  trn_acc: 0.907  (1404.41s - 17.99s remaining)25
# EPOCH: 98.765  trn_loss: 0.136  trn_acc: 0.946  (1404.79s - 17.57s remaining)26
# EPOCH: 98.794  trn_loss: 0.131  trn_acc: 0.945  (1405.17s - 17.15s remaining)27
# EPOCH: 98.824  trn_loss: 0.133  trn_acc: 0.944  (1405.54s - 16.73s remaining)28
# EPOCH: 98.853  trn_loss: 0.117  trn_acc: 0.952  (1405.89s - 16.31s remaining)29
# EPOCH: 98.882  trn_loss: 0.127  trn_acc: 0.946  (1406.25s - 15.89s remaining)30
# EPOCH: 98.912  trn_loss: 0.191  trn_acc: 0.927  (1406.61s - 15.48s remaining)31
# EPOCH: 98.941  trn_loss: 0.120  trn_acc: 0.951  (1406.99s - 15.06s remaining)32
# EPOCH: 98.971  trn_loss: 0.104  trn_acc: 0.960  (1407.35s - 14.64s remaining)33
# EPOCH: 99.000  trn_loss: 0.156  val_loss: 0.291  trn_acc: 0.937  val_acc: 0.896  (1408.49s - 14.23s remaining)
# 0
# EPOCH: 99.029  trn_loss: 0.115  trn_acc: 0.955  (1408.86s - 13.81s remaining)1
# EPOCH: 99.059  trn_loss: 0.129  trn_acc: 0.946  (1409.24s - 13.39s remaining)2
# EPOCH: 99.088  trn_loss: 0.153  trn_acc: 0.939  (1409.60s - 12.97s remaining)3
# EPOCH: 99.118  trn_loss: 0.205  trn_acc: 0.918  (1409.96s - 12.55s remaining)4
# EPOCH: 99.147  trn_loss: 0.189  trn_acc: 0.927  (1410.31s - 12.13s remaining)5
# EPOCH: 99.176  trn_loss: 0.185  trn_acc: 0.922  (1410.68s - 11.71s remaining)6
# EPOCH: 99.206  trn_loss: 0.191  trn_acc: 0.921  (1411.07s - 11.30s remaining)7
# EPOCH: 99.235  trn_loss: 0.126  trn_acc: 0.946  (1411.43s - 10.88s remaining)8
# EPOCH: 99.265  trn_loss: 0.115  trn_acc: 0.953  (1411.79s - 10.46s remaining)9
# EPOCH: 99.294  trn_loss: 0.101  trn_acc: 0.958  (1412.18s - 10.04s remaining)10
# EPOCH: 99.324  trn_loss: 0.186  trn_acc: 0.922  (1412.54s - 9.62s remaining)11
# EPOCH: 99.353  trn_loss: 0.220  trn_acc: 0.911  (1412.89s - 9.20s remaining)12
# EPOCH: 99.382  trn_loss: 0.134  trn_acc: 0.946  (1413.26s - 8.78s remaining)13
# EPOCH: 99.412  trn_loss: 0.229  trn_acc: 0.903  (1413.61s - 8.36s remaining)14
# EPOCH: 99.441  trn_loss: 0.133  trn_acc: 0.952  (1413.97s - 7.95s remaining)15
# EPOCH: 99.471  trn_loss: 0.107  trn_acc: 0.955  (1414.35s - 7.53s remaining)16
# EPOCH: 99.500  trn_loss: 0.106  trn_acc: 0.959  (1414.71s - 7.11s remaining)17
# EPOCH: 99.529  trn_loss: 0.176  trn_acc: 0.926  (1415.11s - 6.69s remaining)18
# EPOCH: 99.559  trn_loss: 0.140  trn_acc: 0.941  (1415.50s - 6.27s remaining)19
# EPOCH: 99.588  trn_loss: 0.171  trn_acc: 0.929  (1415.87s - 5.85s remaining)20
# EPOCH: 99.618  trn_loss: 0.161  trn_acc: 0.932  (1416.25s - 5.44s remaining)21
# EPOCH: 99.647  trn_loss: 0.113  trn_acc: 0.954  (1416.63s - 5.02s remaining)22
# EPOCH: 99.676  trn_loss: 0.173  trn_acc: 0.937  (1416.98s - 4.60s remaining)23
# EPOCH: 99.706  trn_loss: 0.114  trn_acc: 0.954  (1417.36s - 4.18s remaining)24
# EPOCH: 99.735  trn_loss: 0.207  trn_acc: 0.925  (1417.70s - 3.76s remaining)25
# EPOCH: 99.765  trn_loss: 0.152  trn_acc: 0.936  (1418.08s - 3.34s remaining)26
# EPOCH: 99.794  trn_loss: 0.156  trn_acc: 0.938  (1418.44s - 2.93s remaining)27
# EPOCH: 99.824  trn_loss: 0.133  trn_acc: 0.945  (1418.82s - 2.51s remaining)28
# EPOCH: 99.853  trn_loss: 0.137  trn_acc: 0.942  (1419.20s - 2.09s remaining)29
# EPOCH: 99.882  trn_loss: 0.180  trn_acc: 0.932  (1419.58s - 1.67s remaining)30
# EPOCH: 99.912  trn_loss: 0.191  trn_acc: 0.920  (1419.93s - 1.25s remaining)31
# EPOCH: 99.941  trn_loss: 0.112  trn_acc: 0.958  (1420.28s - 0.84s remaining)32
# EPOCH: 99.971  trn_loss: 0.134  trn_acc: 0.947  (1420.64s - 0.42s remaining)33
# EPOCH: 100.000  trn_loss: 0.153  val_loss: 0.340  trn_acc: 0.938  val_acc: 0.893  (1421.78s - 0.00s remaining)

# %%
import torch
import os
from pathlib import Path

def save_model(model, model_name, model_dir='nn_models'):
    """
    Сохраняет обученную модель и веса.
    
    Аргументы:
        model: Обученная модель PyTorch
        model_name: Имя для сохранения модели (без расширения)
        model_dir: Директория для сохранения (по умолчанию 'models')
    """
    # Создаем директорию если не существует
    Path(model_dir).mkdir(parents=True, exist_ok=True)
    
    # Путь для сохранения весов
    weights_path = os.path.join(model_dir, f"{model_name}_weights.pth")
    
    # Путь для сохранения архитектуры модели
    model_path = os.path.join(model_dir, f"{model_name}_model.pth")
    
    # Сохраняем веса
    torch.save(model.state_dict(), weights_path)
    
    # Сохраняем архитектуру модели
    torch.save(model, model_path)
    
    print(f"Модель '{model_name}' успешно сохранена!")
    print(f"Веса: {weights_path}")
    print(f"Архитектура: {model_path}")

# %%
# Сохранение модели
save_model(model, "buildings_segmentation")
# Out:
# Модель 'buildings_segmentation' успешно сохранена!
# Веса: nn_models\buildings_segmentation_weights.pth
# Архитектура: nn_models\buildings_segmentation_model.pth

# %%
# building_segmentation.py
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import cv2
import numpy as np
from pathlib import Path

# Устройство для вычислений
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Трансформации для предобработки изображений
preprocess_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

def load_model(model_dir='nn_models', device=device):
    """
    Загружает сохраненную модель сегментации зданий.
    
    Аргументы:
        model_dir: Директория с сохраненными весами и моделью
        device: Устройство для вычислений
    
    Возвращает:
        Загруженную модель
    """
    # Пути к файлам
    weights_path = Path(model_dir) / 'buildings_segmentation_weights.pth'
    model_path = Path(model_dir) / 'buildings_segmentation_model.pth'
    
    # Проверяем существование файлов
    if not weights_path.exists() or not model_path.exists():
        raise FileNotFoundError(f"Модель не найдена в директории '{model_dir}'")
    
    # Загружаем архитектуру модели
    model = torch.load(model_path, map_location=device)
    
    # Загружаем веса
    model.load_state_dict(torch.load(weights_path, map_location=device))
    
    # Переводим модель в режим оценки
    model.eval()
    
    print(f"Модель успешно загружена на устройство '{device}'")
    
    return model

def preprocess_image(image_path, target_size=(224, 224)):
    """
    Предобработка изображения для модели.
    
    Аргументы:
        image_path: Путь к изображению
        target_size: Целевой размер изображения
    
    Возвращает:
        preprocessed_image: Предобработанное изображение
        original_image: Оригинальное изображение
    """
    # Чтение изображения
    original_image = cv2.imread(image_path)
    if original_image is None:
        raise ValueError(f"Не удалось прочитать изображение: {image_path}")
    
    # Конвертация из BGR в RGB
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    
    # Изменение размера
    resized_image = cv2.resize(original_image, target_size)
    
    # Применение трансформаций
    preprocessed_image = preprocess_transform(resized_image)
    
    return preprocessed_image, original_image

def segment_image(image_path, model, device=device):
    """
    Прогон изображения через модель сегментации.
    
    Аргументы:
        image_path: Путь к изображению
        model: Загруженная модель
        device: Устройство для вычислений
    
    Возвращает:
        mask: Массив с маской сегментации
        original_image: Оригинальное изображение
    """
    # Предобработка изображения
    preprocessed_image, original_image = preprocess_image(image_path)
    
    # Добавляем batch dimension
    input_tensor = preprocessed_image.unsqueeze(0).to(device)
    
    # Прогон через модель
    with torch.no_grad():
        output = model(input_tensor)
    
    # Получаем маску
    _, predicted = torch.max(output, dim=1)
    mask = predicted.squeeze(0).cpu().numpy()
    
    return mask, original_image

def visualize_segmentation(mask, original_image):
    """
    Визуализация результата сегментации.
    
    Аргументы:
        mask: Массив с маской сегментации
        original_image: Оригинальное изображение
    
    Возвращает:
        Результат визуализации
    """
    
    # Изменяем размер маски до оригинальных размеров изображения
    mask_resized = cv2.resize(mask.astype(np.uint8), (original_image.shape[1], original_image.shape[0]), 
                             interpolation=cv2.INTER_NEAREST)
    
    # Создаем цветную маску из измененной маски
    colored_mask = cv2.applyColorMap(mask_resized, cv2.COLORMAP_JET)
    
    # Наложение маски на оригинальное изображение
    alpha = 0.5
    blended = cv2.addWeighted(original_image, alpha, colored_mask, 1 - alpha, 0)
    
    return blended

# Загружаем модель
model = load_model()
    
# Путь к тестовому изображению
test_image_path = r'C:\Users\Kirilll\Desktop\train_105.png'
    
# Прогон изображения через модель
mask, original_image = segment_image(test_image_path, model)
    
# Визуализация результата
result = visualize_segmentation(mask, original_image)
    
# Сохранение результата
cv2.imwrite('segmentation_result0.jpg', cv2.cvtColor(result, cv2.COLOR_RGB2BGR))
    
print(f"Результат сегментации сохранен как 'segmentation_result.jpg'")
# Out:
# C:\Users\Kirilll\AppData\Local\Temp\ipykernel_5180\2330305219.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path, map_location=device)
# C:\Users\Kirilll\AppData\Local\Temp\ipykernel_5180\2330305219.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights_path, map_location=device))
# Модель успешно загружена на устройство 'cuda'
# Результат сегментации сохранен как 'segmentation_result.jpg'

# %%
plt.imshow(mask)

# %%
plt.imshow(original_image)

# %%
log.plot_epochs(['trn_loss', 'val_loss'])
# Out:
# 100%|██████████| 156/156 [00:00<00:00, 4875.10it/s]

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#a7fabd;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 100px 50px;overflow:hidden;font-weight:500">Testing</p>

# %%
im, mask = next(iter(tst_dl))
_mask = model(im)
_, _mask = torch.max(_mask, dim=1)
subplots([im[0].permute(1,2,0).detach().cpu()[:,:,0], mask.permute(1,2,0).detach().cpu()[:,:,0]
,_mask.permute(1,2,0).detach().cpu()[:,:,0]],
nc=3, titles=['Original image','Original mask','Predicted mask'])

# %%
# plt.imshow(mask.permute(1,2,0).detach().cpu()[:,:,0])
plt.imshow(_mask.permute(1,2,0).detach().cpu()[:,:,0])

# %%
plt.imshow(mask.permute(1,2,0).detach().cpu()[:,:,0])

# %% [markdown]
# ---
