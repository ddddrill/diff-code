# %% [markdown]
# Расчет мощности излучения, необходимой для осуществления радиосвязи заданного вида,
# производится по формуле (1) из приложения к варианту 1.

# %% [markdown]
# Рассчет проводим для волн длиной
# λ=3 , 15, 30, 150, 300 сантимеров
# 2-х значений коэф. шима   N= 1, 10
# Яркостная температура земли 300 К

# %% [markdown]
# Данные нам величины
# D1=D2= 1
# η2= 0,84
# h= 750 км
# r= ? км
# Δf= 0,25 кГц
# Вид радиосвязи - телеграфия
#
# β – коэффициент различимости по напряженности поля (5,10);
# А2 – эффективная площадь приемной антенны, м2;
# D1 – коэффициент направленного действия передающей антенны;
# r – протяженность радиолинии, м;
# Δf – полоса пропускания приемника, Гц;
# q – коэффициент согласования; при отсутствии указаний полагать q = 1;
# ТА – шумовая температура приемной антенны, К;
# W – множитель ослабления;
# T0- температура при которой измеряеться коэф шума (Т0=300 К)
# Rз- радиус земли

# %%
A2=2.1 # эффективная площадь раскрыва
η2= 0.89
h= 300   # длина радиолинии в километрах
O=2.2
Δf= 5500*(10**3)  # полоса пропускания 
T0=300
radius=6370 # радиус земли в километрах

# %% [markdown]
# ### Сначала выполним расчеты для N=1

# %%
N_1=1

# %% [markdown]
# Шумовая температура радиоприемного устройства приближенно равна
# Tшрпу=(N-η2)*T0

# %%
Tnrpu_1=(N_1-η2)*T0
print(Tnrpu_1)
# Out:
# 32.99999999999999

# %% [markdown]
# Шумовая температура ненаправленной (реально – слабонаправленной) антенны вычисляется по формуле,
# где T_le-яркостная температура шумов Земли,T_cos-яркостная температура космических шумов
# T_cos для каждой волны своя

# %%
# для 3 см
t_cos=0
t_le=300
t_a_3=(1/2)*(t_le*(1-(1-(radius/(radius+h))**2)**(1/2))+t_cos*(1+(1-(radius/(radius+h))**2)**(1/2)))
print ('Для 3 см '+f'{t_a_3} K')

# для 15 см
t_cos=8
t_le=300
t_a_15=(1/2)*(t_le*(1-(1-(radius/(radius+h))**2)**(1/2))+t_cos*(1+(1-(radius/(radius+h))**2)**(1/2)))
print('Для 15 см '+f'{t_a_15} K')

# для 30 см
t_cos=40
t_le=300
t_a_30=(1/2)*(t_le*(1-(1-(radius/(radius+h))**2)**(1/2))+t_cos*(1+(1-(radius/(radius+h))**2)**(1/2)))
print('Для 30 см '+f'{t_a_30} K')

# для 150 см
t_cos=1000
t_le=300
t_a_150=(1/2)*(t_le*(1-(1-(radius/(radius+h))**2)**(1/2))+t_cos*(1+(1-(radius/(radius+h))**2)**(1/2)))
print('Для 150 см '+f'{t_a_150} K')

# для 300 см
t_cos=7000
t_le=300
t_a_300=(1/2)*(t_le*(1-(1-(radius/(radius+h))**2)**(1/2))+t_cos*(1+(1-(radius/(radius+h))**2)**(1/2)))
print('Для 300 см '+f'{t_a_300} K')
# Out:
# Для 3 см 105.51999286929134 K
# Для 15 см 110.70612639277691 K
# Для 30 см 131.45066048671916 K
# Для 150 см 753.7866833049868 K
# Для 300 см 4643.3868259191595 K

# %% [markdown]
# расчитаем длину радиолинии в метрах

# %%
rad=6370*(10**3)    # Радиус земли в метрах
hi=300*(10**3)      # Высота в метрах

# %%
r=2*((((rad+hi)**2)-((rad)**2))**(1/2)) # длина радиолинии в метрах
print(r)
# Out:
# 3955755.300824357

# %%
D1=(25*(10**3))/(O**2)
print(D1)
# Out:
# 5165.289256198346

# %% [markdown]
# Ввиду того, что A1*D2=(с формулы сиотри)D2*D1 можно посчитать их произведение

# %%
a2_d1=D1*A2

print(f'Эквивалент знвчения A1D2 = {a2_d1}')
# Out:
# Эквивалент знвчения A1D2 = 10847.107438016528

# %%
W=1

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=1

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=5

# %%
β_10=200

# %%
P_1_5_3= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_3 +1*(Tnrpu_1/η2) )
P_1_5_15= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_15 +1*(Tnrpu_1/η2) )
P_1_5_30= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_30 +1*(Tnrpu_1/η2) )
P_1_5_150= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_150 +1*(Tnrpu_1/η2) )
P_1_5_300= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_300 +1*(Tnrpu_1/η2) )
print('Расчет мощности излучения для длины волны 3 см '+f'{P_1_5_3} Вт')
print('Расчет мощности излучения для длины волны 15 см '+f'{P_1_5_15} Вт')
print('Расчет мощности излучения для длины волны 30 см '+f'{P_1_5_30} Вт')
print('Расчет мощности излучения для длины волны 150 см '+f'{P_1_5_150} Вт')
print('Расчет мощности излучения для длины волны 300 см '+f'{P_1_5_300} Вт')
# Out:
# Расчет мощности излучения для длины волны 3 см 7.848234323611898 Вт
# Расчет мощности излучения для длины волны 15 см 8.133664744447666 Вт
# Расчет мощности излучения для длины волны 30 см 9.275386427790737 Вт
# Расчет мощности излучения для длины волны 150 см 43.527036928082886 Вт
# Расчет мощности излучения для длины волны 300 см 257.59985255490886 Вт

# %% [markdown]
# ### Теперь посчитаем для N=10

# %%
N_10=10

# %%
Tnrpu_10=(N_10-η2)*T0
print(Tnrpu_10)
# Out:
# 2733.0

# %% [markdown]
# Посчитаем мощность излучаемого сигнала для β=5

# %%
P_10_5_3= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_3 +1*(Tnrpu_10/η2) )
P_10_5_15= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_15 +1*(Tnrpu_10/η2) )
P_10_5_30= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_30 +1*(Tnrpu_10/η2) )
P_10_5_150= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_150 +1*(Tnrpu_10/η2) )
P_10_5_300= (β_10**2)* ( (4*(355/113)*(r**2)) / (a2_d1*(W**2))) * ((138/100)*(10**(-23))) * (Δf) * ( t_a_300 +1*(Tnrpu_10/η2) )
print('Расчет мощности излучения для длины волны 3 см '+f'{P_10_5_3} Вт')
print('Расчет мощности излучения для длины волны 15 см '+f'{P_10_5_15} Вт')
print('Расчет мощности излучения для длины волны 30 см '+f'{P_10_5_30} Вт')
print('Расчет мощности излучения для длины волны 150 см '+f'{P_10_5_150} Вт')
print('Расчет мощности излучения для длины волны 300 см '+f'{P_10_5_300} Вт')
# Out:
# Расчет мощности излучения для длины волны 3 см 174.81511026819067 Вт
# Расчет мощности излучения для длины волны 15 см 175.10054068902642 Вт
# Расчет мощности излучения для длины волны 30 см 176.2422623723695 Вт
# Расчет мощности излучения для длины волны 150 см 210.49391287266167 Вт
# Расчет мощности излучения для длины волны 300 см 424.5667284994876 Вт
